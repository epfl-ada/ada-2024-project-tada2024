# %% [markdown]
# # CLUSTERING MODELS
#
# ### Clustering Workflow Overview:
# 1. **Define Clustering Methods**
#    Define functions for the following 5 clustering methods:
#    - K-Means
#    - K-Medoids with euclidean distance
#    - K-Medoids with cosine similarity (transfered to distance)
#    - Spectral Clustering with euclidean distance (transfered to similarity)
#    - Spectral Clustering with cosine similarity
#
# 2. **Set Number of Clusters**
#    Calculate the number of original categories and set the clustering count to match this number.
#
# 3. **Execute Clustering and Save Results**
#    Perform clustering using each method and store results in dictionary format.
#    Save all clustering results as a pickle file in the directory `./output/clustering/`.

# %%
import pandas as pd
import numpy as np
import warnings
import os

warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1 K-MEANS (with raw data)

# %%
from sklearn.cluster import KMeans

def Kmeans_Raw(data,n_clusters,state=520):
    # Apply K-means clustering with 3 clusters
    kmeans = KMeans(n_clusters=n_clusters, random_state=state)
    kmeans.fit(data)

    return kmeans.labels_

# %% [markdown]
# ## 2 KMedoids (with distance matrix)
# - This method needs to use distance data

# %%
try:
    from sklearn_extra.cluster import KMedoids
except Exception as e:
    print('installing scikit-learn-extra package')
    
    # !pip install scikit-learn-extra
    
    from sklearn_extra.cluster import KMedoids

# %% [markdown]
# ### 2.1 Euclidean Distance

# %%
from sklearn.metrics.pairwise import euclidean_distances

def Kmedoids_Euc(data,n_clusters,state=520):

    # Calculate the semnatic distance using euclidean distance
    euclindean_distance = euclidean_distances(data)

    # Perform KMedoids
    kmedoids_euc = KMedoids(n_clusters=n_clusters, metric="precomputed",random_state=state)
    kmedoids_euc.fit(euclindean_distance)

    return kmedoids_euc.labels_

# %% [markdown]
# ### 2.2 Cosine Similarity - Distance

# %%
from sklearn.metrics.pairwise import cosine_similarity

def Kmedoids_Cos(data,n_clusters,state=520):
    
    ## Calculate the semnatic distance using cosine similarity
    cosine_sim = cosine_similarity(data)

    # transfer similarity to distance
    cosine_distance = 1 - 0.5 * (cosine_sim + 1)
    cosine_distance = np.clip(cosine_distance, 0, None) # Make sure there is no negative values

    # Perform KMedoids
    kmedoids_cos = KMedoids(n_clusters=n_clusters, metric="precomputed",random_state=state)
    kmedoids_cos.fit(cosine_distance)

    return kmedoids_cos.labels_

# %% [markdown]
# ## 3 Spectral Clustering (with similarity matrix)
# - This method needs to use similarity

# %%
from sklearn.cluster import SpectralClustering

# %% [markdown]
# ### 2.1 Euclidean Distance - Similarity

# %%
from sklearn.metrics.pairwise import euclidean_distances

def Spectral_Euc(data,n_clusters,state=520):

    # Calculate the semnatic distance using euclidean distance
    euclidean_distance = euclidean_distances(data)

    # Here we use a Gaussian (RBF) kernel to transform distances to similarities.
    sigma = np.median(euclidean_distance)  # Using the median distance as sigma for the RBF kernel
    euclidean_similarity = np.exp(-euclidean_distance ** 2 / (2. * sigma ** 2))

    # Perform clustery
    spectral_euc = SpectralClustering(n_clusters=n_clusters, affinity='precomputed',random_state = state)
    spectral_euc_labels = spectral_euc.fit_predict(euclidean_similarity)

    return spectral_euc_labels

# %% [markdown]
# ### 2.2 Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

def Spectral_Cos(data,n_clusters,state=520):

    # Calculate the semantic similarity using cosine similarity
    cos_similarity = cosine_similarity(data)
    cos_similarity = np.clip(cos_similarity, 0, None) # make sure there is no negative values

    # Perform clustery
    spectral_cos = SpectralClustering(n_clusters=n_clusters, affinity='precomputed',random_state=state)
    spectral_cos_labels = spectral_cos.fit_predict(cos_similarity)

    return spectral_cos_labels

# %% [markdown]
# ## 4. Calculate the amount of original categories

# %%
# We need to keep the clustering number is equal to the amount of original categories
file_path = './/dataset//wikispeedia_paths-and-graph//categories.tsv'
category_df = pd.read_csv(file_path, sep='\t', skiprows=12,header=None)
category_df.columns = ['concept','category']

# %%
# the type of data is dict
print('The total number of articles in the category_dataset is: {}'.format(category_df.shape[0]))
# Out:
# The total number of articles in the category_dataset is: 5204

# %%
# Collect all primary categories
category_df['primary_category'] = category_df['category'].apply(lambda x: x.split('.')[1])
print('The orginal primary categories are:')
print(category_df['primary_category'].unique())

# Set the number of clustering
n_clusters = len(category_df['primary_category'].unique())
print('The clustering number we need to set is: {}'.format(n_clusters))
# Out:
# The orginal primary categories are:
# ['History' 'People' 'Countries' 'Geography' 'Business_Studies' 'Science'
#  'Everyday_life' 'Design_and_Technology' 'Music' 'IT'
#  'Language_and_literature' 'Mathematics' 'Religion' 'Art' 'Citizenship']
# The clustering number we need to set is: 15

# %% [markdown]
# ## 5. Perform Clustering and Save results

# %% [markdown]
# ### 5.1 Read the embedding data

# %%
import pickle

# Set the embedding file path
file_path = './/output//embeddings//all_mpnet_base_v2//20241109_150434//embeddings.pkl'
saved_path = './/output//clustering//all_mpnet_base_v2'

# Read the file and print embeddings
with open(file_path, 'rb') as file:
    embedding = pickle.load(file)
    embedding_values = list(embedding.values())

print('The total number of articles in the category_dataset is: {}'.format(len(embedding_values)))
# Out:
# The total number of articles in the category_dataset is: 4604

# %%
# Set the embedding file path

file_path = './/output//embeddings//all_MiniLM_L6_v2//20241109_104244//embeddings.pkl'
saved_path = './/output//clustering//all_MiniLM_L6_v2'

# Read the file and print embeddings
with open(file_path, 'rb') as file:
    embedding = pickle.load(file)
    embedding_values = list(embedding.values())

print('The total number of articles in the category_dataset is: {}'.format(len(embedding_values)))
# Out:
# The total number of articles in the category_dataset is: 5232

# %% [markdown]
# ### 5.2 Perform K-MEANS Clustering

# %%
# Calling the function
Kmeans_Clustering = Kmeans_Raw(embedding_values,n_clusters)

# Transfer the result into dict
Kmeans_result = dict(zip(list(embedding.keys()), Kmeans_Clustering))
print("K-means Cluster labels:")
print(Kmeans_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Kmeans_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//KMeans.pkl', 'wb') as f:
    pickle.dump(Kmeans_result, f)
# Out:
# K-means Cluster labels:
# {'%C3%81ed%C3%A1n_mac_Gabr%C3%A1in': 1, '%C3%85land': 9, '%C3%89douard_Manet': 3, '%C3%89ire': 9, '%C3%93engus_I_of_the_Picts': 1, '%E2%82%AC2_commemorative_coins': 9, '10th_century': 1, '11th_century': 1, '12th_century': 1, '13th_century': 1, '14th_century': 1, '15th_century': 1, '15th_Marine_Expeditionary_Unit': 10, '16th_century': 1, '16_Cygni': 6, '16_Cygni_Bb': 6, '1755_Lisbon_earthquake': 7, '17th_century': 9, '1896_Summer_Olympics': 1, '18th_century': 0, '1928_Okeechobee_Hurricane': 7, '1973_oil_crisis': 9, '1980_eruption_of_Mount_St._Helens': 7, '1997_Pacific_hurricane_season': 7, '19th_century': 9, '1st_century': 1, '1st_century_BC': 1, '1_Ceres': 6, '2-6-0': 10, '2-8-0': 10, '2003_Atlantic_hurricane_season': 7, '2004_Atlantic_hurricane_season': 7, '2004_Indian_Ocean_earthquake': 7, '2005_Atlantic_hurricane_season': 7, '2005_Hertfordshire_Oil_Storage_Terminal_fire': 7, '2005_Kashmir_earthquake': 7, '2005_Lake_Tanganyika_earthquake': 7, '2005_Sumatra_earthquake': 7, '20th_century': 10, '21st_century': 9, '2nd_century': 1, '3rd_century': 1, '3_Juno': 6, '4-2-0': 10, '4-4-0': 10, '4-6-0': 10, '47_Ursae_Majoris': 6, '47_Ursae_Majoris_b': 6, '47_Ursae_Majoris_c': 6, '4th_century': 1, '4_Vesta': 6, '55_Cancri': 6, '55_Cancri_b': 6, '55_Cancri_c': 6, '55_Cancri_d': 6, '55_Cancri_e': 6, '5th_century': 1, '6-2-0': 10, '6th_century': 1, '7th_century': 1, '8th_century': 1, '90377_Sedna': 6, '9th_century': 1, 'A._E._J._Collins': 12, 'Aachen': 4, 'Aardvark': 2, 'Aarhus': 4, 'Abac%C3%A1': 14, 'Abacus': 11, 'Abadan': 1, 'Abbadid': 1, 'Abbasid': 1, 'Abbas_I_of_Persia': 1, 'Abbey': 0, 'Abbey_Theatre': 0, 'Abbot': 1, 'Abel_Tasman': 8, 'Aberdeen': 0, 'Aberration_of_light': 6, 'Aberystwyth': 4, 'Abhidhamma_Pitaka': 11, 'Abidjan': 8, 'Abkhazia': 9, 'Able_Archer_83': 12, 'ABO_blood_group_system': 11, 'Abraham_Goldfaden': 3, 'Abraham_Lincoln': 12, 'Absinthe': 14, 'Absolute_zero': 11, 'Abstract_art': 11, 'Abuja': 4, 'Abu_Dhabi': 4, 'Acceleration': 11, 'Accountancy': 11, 'Accra': 8, 'Acetic_acid': 14, 'Acetone': 13, 'Achilles': 1, 'Achilles_tendon': 1, 'Acid_rain': 7, 'Acorn_Computers': 10, 'Actinium': 13, 'Action_potential': 11, 'Actor': 11, 'Acts_of_Union_1707': 0, 'Actuary': 11, 'AC_DC': 10, 'Adam_Smith': 3, 'Addis_Ababa': 8, 'Adelaide': 4, 'Adenosine_triphosphate': 11, 'Adi_Shankara': 11, 'Adolf_Hitler': 12, 'Adriaen_van_der_Donck': 3, 'Advertising': 10, 'Aesthetics': 11, 'Afghanistan': 9, 'Afghan_Hound': 5, 'Africa': 8, 'African_American_literature': 3, 'African_Black_Oystercatcher': 5, 'African_Brush-tailed_Porcupine': 5, 'African_Buffalo': 2, 'African_clawed_frog': 2, 'African_Darter': 5, 'African_dwarf_frog': 2, 'African_Great_Lakes': 4, 'African_Grey_Hornbill': 5, 'African_Grey_Parrot': 5, 'African_Jacana': 5, 'African_Penguin': 5, 'African_slave_trade': 8, 'African_Union': 9, 'African_Wild_Dog': 5, 'Afrikaans': 8, 'Agamemnon': 1, 'Age_of_Enlightenment': 3, 'Aggregator': 10, 'Agnosticism': 11, 'Agriculture': 11, 'AIDS': 11, 'Airbus': 10, 'Airbus_A380': 10, 'Aircraft': 10, 'Aircraft_carrier': 10, 'Airship': 10, 'Ajax_%28programming%29': 10, 'AK-47': 10, 'Akbar': 1, 'Akhenaten': 1, 'Akira_Kurosawa': 3, 'Akkadian_Empire': 1, 'Akrotiri_and_Dhekelia': 8, 'Aksumite_currency': 1, 'Alamosaurus': 2, 'Alan_Turing': 3, 'Albania': 1, 'Albatross': 5, 'Albertosaurus': 2, 'Alberto_Santos-Dumont': 3, 'Albert_Einstein': 3, 'Albigensian_Crusade': 1, 'Albinism': 11, 'Albrecht_D%C3%BCrer': 3, 'Albrecht_Rodenbach': 3, 'Alchemy': 13, 'Alcibiades': 1, 'Alcohol': 14, 'ALCO_FA': 10, 'Aleksandr_Pushkin': 3, 'Aleksandr_Vasilevsky': 12, 'Aleksey_Arakcheyev': 3, 'Alexander_Graham_Bell': 3, 'Alexander_Hamilton': 12, 'Alexander_the_Great': 1, 'Alfred_Hitchcock': 3, 'Alfred_Nobel': 3, 'Alfred_the_Great': 0, 'Algebra': 11, 'Algeria': 8, 'Algerian_Civil_War': 9, 'Algiers': 8, 'Algol': 6, 'Algoma_Central_Railway': 10, 'Algorithm': 11, 'Alice%27s_Adventures_in_Wonderland': 3, 'Allah': 1, 'Allegory_in_the_Middle_Ages': 1, 'Alligator': 2, 'Alliterative_verse': 1, 'Allosa ...
# 10    540
# 11    472
# 12    372
# 4     368
# 3     363
# 0     342
# 1     338
# 9     334
# 8     297
# 2     260
# 14    215
# 13    206
# 5     198
# 6     162
# 7     137
# Name: count, dtype: int64

# %% [markdown]
# ### 5.3 Perform K-Medoids Clustering with Euclidean Distance

# %%
# Calling the function
Kmedoids_Euc_Clustering = Kmedoids_Euc(embedding_values,n_clusters)

# Transfer the result into dict
Kmedoids_Euc_result = dict(zip(list(embedding.keys()), Kmedoids_Euc_Clustering))
print("Kmedoids_Euc Cluster labels:")
print(Kmedoids_Euc_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Kmedoids_Euc_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Kmedoids_Euc.pkl', 'wb') as f:
    pickle.dump(Kmedoids_Euc_result, f)
# Out:
# Kmedoids_Euc Cluster labels:
# {'%C3%81ed%C3%A1n_mac_Gabr%C3%A1in': 2, '%C3%85land': 2, '%C3%89douard_Manet': 1, '%C3%89ire': 2, '%C3%93engus_I_of_the_Picts': 8, '%E2%82%AC2_commemorative_coins': 2, '10th_century': 9, '11th_century': 2, '12th_century': 8, '13th_century': 13, '14th_century': 1, '15th_century': 9, '15th_Marine_Expeditionary_Unit': 2, '16th_century': 9, '16_Cygni': 11, '16_Cygni_Bb': 11, '1755_Lisbon_earthquake': 10, '17th_century': 8, '1896_Summer_Olympics': 1, '18th_century': 8, '1928_Okeechobee_Hurricane': 10, '1973_oil_crisis': 11, '1980_eruption_of_Mount_St._Helens': 6, '1997_Pacific_hurricane_season': 11, '19th_century': 0, '1st_century': 3, '1st_century_BC': 13, '1_Ceres': 6, '2-6-0': 13, '2-8-0': 13, '2003_Atlantic_hurricane_season': 10, '2004_Atlantic_hurricane_season': 10, '2004_Indian_Ocean_earthquake': 11, '2005_Atlantic_hurricane_season': 10, '2005_Hertfordshire_Oil_Storage_Terminal_fire': 0, '2005_Kashmir_earthquake': 7, '2005_Lake_Tanganyika_earthquake': 4, '2005_Sumatra_earthquake': 11, '20th_century': 9, '21st_century': 9, '2nd_century': 9, '3rd_century': 3, '3_Juno': 6, '4-2-0': 10, '4-4-0': 10, '4-6-0': 10, '47_Ursae_Majoris': 11, '47_Ursae_Majoris_b': 11, '47_Ursae_Majoris_c': 11, '4th_century': 9, '4_Vesta': 6, '55_Cancri': 11, '55_Cancri_b': 11, '55_Cancri_c': 11, '55_Cancri_d': 11, '55_Cancri_e': 11, '5th_century': 9, '6-2-0': 3, '6th_century': 9, '7th_century': 9, '8th_century': 3, '90377_Sedna': 11, '9th_century': 3, 'A._E._J._Collins': 8, 'Aachen': 5, 'Aardvark': 4, 'Aarhus': 14, 'Abac%C3%A1': 4, 'Abacus': 3, 'Abadan': 1, 'Abbadid': 14, 'Abbasid': 1, 'Abbas_I_of_Persia': 8, 'Abbey': 14, 'Abbey_Theatre': 8, 'Abbot': 1, 'Abel_Tasman': 12, 'Aberdeen': 14, 'Aberration_of_light': 6, 'Aberystwyth': 5, 'Abhidhamma_Pitaka': 9, 'Abidjan': 4, 'Abkhazia': 0, 'Able_Archer_83': 4, 'ABO_blood_group_system': 9, 'Abraham_Goldfaden': 1, 'Abraham_Lincoln': 8, 'Absinthe': 4, 'Absolute_zero': 3, 'Abstract_art': 9, 'Abuja': 4, 'Abu_Dhabi': 12, 'Acceleration': 6, 'Accountancy': 6, 'Accra': 4, 'Acetic_acid': 13, 'Acetone': 0, 'Achilles': 1, 'Achilles_tendon': 1, 'Acid_rain': 11, 'Acorn_Computers': 3, 'Actinium': 6, 'Action_potential': 5, 'Actor': 1, 'Acts_of_Union_1707': 2, 'Actuary': 9, 'AC_DC': 12, 'Adam_Smith': 8, 'Addis_Ababa': 4, 'Adelaide': 12, 'Adenosine_triphosphate': 11, 'Adi_Shankara': 1, 'Adolf_Hitler': 8, 'Adriaen_van_der_Donck': 14, 'Advertising': 3, 'Aesthetics': 6, 'Afghanistan': 1, 'Afghan_Hound': 5, 'Africa': 4, 'African_American_literature': 9, 'African_Black_Oystercatcher': 4, 'African_Brush-tailed_Porcupine': 4, 'African_Buffalo': 4, 'African_clawed_frog': 4, 'African_Darter': 4, 'African_dwarf_frog': 4, 'African_Great_Lakes': 4, 'African_Grey_Hornbill': 4, 'African_Grey_Parrot': 4, 'African_Jacana': 4, 'African_Penguin': 4, 'African_slave_trade': 4, 'African_Union': 4, 'African_Wild_Dog': 4, 'Afrikaans': 4, 'Agamemnon': 1, 'Age_of_Enlightenment': 8, 'Aggregator': 5, 'Agnosticism': 9, 'Agriculture': 9, 'AIDS': 4, 'Airbus': 4, 'Airbus_A380': 4, 'Aircraft': 2, 'Aircraft_carrier': 7, 'Airship': 2, 'Ajax_%28programming%29': 3, 'AK-47': 4, 'Akbar': 8, 'Akhenaten': 1, 'Akira_Kurosawa': 9, 'Akkadian_Empire': 1, 'Akrotiri_and_Dhekelia': 2, 'Aksumite_currency': 4, 'Alamosaurus': 6, 'Alan_Turing': 3, 'Albania': 1, 'Albatross': 7, 'Albertosaurus': 10, 'Alberto_Santos-Dumont': 10, 'Albert_Einstein': 6, 'Albigensian_Crusade': 8, 'Albinism': 4, 'Albrecht_D%C3%BCrer': 9, 'Albrecht_Rodenbach': 8, 'Alchemy': 6, 'Alcibiades': 1, 'Alcohol': 2, 'ALCO_FA': 13, 'Aleksandr_Pushkin': 14, 'Aleksandr_Vasilevsky': 8, 'Aleksey_Arakcheyev': 8, 'Alexander_Graham_Bell': 10, 'Alexander_Hamilton': 8, 'Alexander_the_Great': 1, 'Alfred_Hitchcock': 8, 'Alfred_Nobel': 6, 'Alfred_the_Great': 8, 'Algebra': 9, 'Algeria': 4, 'Algerian_Civil_War': 8, 'Algiers': 4, 'Algol': 1, 'Algoma_Central_Railway': 10, 'Algorithm': 3, 'Alice%27s_Adventures_in_Wonderland': 14, 'Allah': 1, 'Allegory_in_the_Middle_Ages': 9, 'Alligator': 10, 'Alliterative_verse': 3, 'Allosaurus': ...
# 8     462
# 6     457
# 9     402
# 10    354
# 5     351
# 14    330
# 4     324
# 2     299
# 13    279
# 1     261
# 0     246
# 3     245
# 11    232
# 12    230
# 7     132
# Name: count, dtype: int64

# %% [markdown]
# ### 5.4 Perform K-Medoids Clustering with cosine similarity

# %%
# Calling the function
Kmedoids_Cos_Clustering = Kmedoids_Cos(embedding_values,n_clusters)

# Transfer the result into dict
Kmedoids_Cos_result = dict(zip(list(embedding.keys()), Kmedoids_Cos_Clustering))
print("Kmedoids_Cos Cluster labels:")
print(Kmedoids_Cos_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Kmedoids_Cos_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Kmedoids_Cos.pkl', 'wb') as f:
    pickle.dump(Kmedoids_Cos_result, f)
# Out:
# Kmedoids_Cos Cluster labels:
# {'%C3%81ed%C3%A1n_mac_Gabr%C3%A1in': 0, '%C3%85land': 0, '%C3%89douard_Manet': 5, '%C3%89ire': 0, '%C3%93engus_I_of_the_Picts': 6, '%E2%82%AC2_commemorative_coins': 0, '10th_century': 1, '11th_century': 0, '12th_century': 6, '13th_century': 12, '14th_century': 5, '15th_century': 1, '15th_Marine_Expeditionary_Unit': 0, '16th_century': 1, '16_Cygni': 13, '16_Cygni_Bb': 13, '1755_Lisbon_earthquake': 3, '17th_century': 6, '1896_Summer_Olympics': 5, '18th_century': 6, '1928_Okeechobee_Hurricane': 3, '1973_oil_crisis': 13, '1980_eruption_of_Mount_St._Helens': 9, '1997_Pacific_hurricane_season': 13, '19th_century': 2, '1st_century': 8, '1st_century_BC': 12, '1_Ceres': 9, '2-6-0': 12, '2-8-0': 12, '2003_Atlantic_hurricane_season': 3, '2004_Atlantic_hurricane_season': 3, '2004_Indian_Ocean_earthquake': 13, '2005_Atlantic_hurricane_season': 3, '2005_Hertfordshire_Oil_Storage_Terminal_fire': 2, '2005_Kashmir_earthquake': 10, '2005_Lake_Tanganyika_earthquake': 4, '2005_Sumatra_earthquake': 13, '20th_century': 1, '21st_century': 1, '2nd_century': 1, '3rd_century': 8, '3_Juno': 9, '4-2-0': 3, '4-4-0': 3, '4-6-0': 3, '47_Ursae_Majoris': 13, '47_Ursae_Majoris_b': 13, '47_Ursae_Majoris_c': 13, '4th_century': 1, '4_Vesta': 9, '55_Cancri': 13, '55_Cancri_b': 13, '55_Cancri_c': 13, '55_Cancri_d': 13, '55_Cancri_e': 13, '5th_century': 1, '6-2-0': 8, '6th_century': 1, '7th_century': 1, '8th_century': 8, '90377_Sedna': 13, '9th_century': 8, 'A._E._J._Collins': 6, 'Aachen': 7, 'Aardvark': 4, 'Aarhus': 11, 'Abac%C3%A1': 4, 'Abacus': 8, 'Abadan': 5, 'Abbadid': 11, 'Abbasid': 5, 'Abbas_I_of_Persia': 6, 'Abbey': 11, 'Abbey_Theatre': 6, 'Abbot': 5, 'Abel_Tasman': 14, 'Aberdeen': 11, 'Aberration_of_light': 9, 'Aberystwyth': 7, 'Abhidhamma_Pitaka': 1, 'Abidjan': 4, 'Abkhazia': 2, 'Able_Archer_83': 4, 'ABO_blood_group_system': 1, 'Abraham_Goldfaden': 5, 'Abraham_Lincoln': 6, 'Absinthe': 4, 'Absolute_zero': 8, 'Abstract_art': 1, 'Abuja': 4, 'Abu_Dhabi': 14, 'Acceleration': 9, 'Accountancy': 9, 'Accra': 4, 'Acetic_acid': 12, 'Acetone': 2, 'Achilles': 5, 'Achilles_tendon': 5, 'Acid_rain': 13, 'Acorn_Computers': 8, 'Actinium': 9, 'Action_potential': 7, 'Actor': 5, 'Acts_of_Union_1707': 0, 'Actuary': 1, 'AC_DC': 14, 'Adam_Smith': 6, 'Addis_Ababa': 4, 'Adelaide': 14, 'Adenosine_triphosphate': 13, 'Adi_Shankara': 5, 'Adolf_Hitler': 6, 'Adriaen_van_der_Donck': 11, 'Advertising': 8, 'Aesthetics': 9, 'Afghanistan': 5, 'Afghan_Hound': 7, 'Africa': 4, 'African_American_literature': 1, 'African_Black_Oystercatcher': 4, 'African_Brush-tailed_Porcupine': 4, 'African_Buffalo': 4, 'African_clawed_frog': 4, 'African_Darter': 4, 'African_dwarf_frog': 4, 'African_Great_Lakes': 4, 'African_Grey_Hornbill': 4, 'African_Grey_Parrot': 4, 'African_Jacana': 4, 'African_Penguin': 4, 'African_slave_trade': 4, 'African_Union': 4, 'African_Wild_Dog': 4, 'Afrikaans': 4, 'Agamemnon': 5, 'Age_of_Enlightenment': 6, 'Aggregator': 7, 'Agnosticism': 1, 'Agriculture': 1, 'AIDS': 4, 'Airbus': 4, 'Airbus_A380': 4, 'Aircraft': 0, 'Aircraft_carrier': 10, 'Airship': 0, 'Ajax_%28programming%29': 8, 'AK-47': 4, 'Akbar': 6, 'Akhenaten': 5, 'Akira_Kurosawa': 1, 'Akkadian_Empire': 5, 'Akrotiri_and_Dhekelia': 0, 'Aksumite_currency': 4, 'Alamosaurus': 9, 'Alan_Turing': 8, 'Albania': 5, 'Albatross': 10, 'Albertosaurus': 3, 'Alberto_Santos-Dumont': 3, 'Albert_Einstein': 9, 'Albigensian_Crusade': 6, 'Albinism': 4, 'Albrecht_D%C3%BCrer': 1, 'Albrecht_Rodenbach': 6, 'Alchemy': 9, 'Alcibiades': 5, 'Alcohol': 0, 'ALCO_FA': 12, 'Aleksandr_Pushkin': 11, 'Aleksandr_Vasilevsky': 6, 'Aleksey_Arakcheyev': 6, 'Alexander_Graham_Bell': 3, 'Alexander_Hamilton': 6, 'Alexander_the_Great': 5, 'Alfred_Hitchcock': 6, 'Alfred_Nobel': 9, 'Alfred_the_Great': 6, 'Algebra': 1, 'Algeria': 4, 'Algerian_Civil_War': 6, 'Algiers': 4, 'Algol': 5, 'Algoma_Central_Railway': 3, 'Algorithm': 8, 'Alice%27s_Adventures_in_Wonderland': 11, 'Allah': 5, 'Allegory_in_the_Middle_Ages': 1, 'Alligator': 3, 'Alliterative_verse': 8, 'Allosaurus': 4, 'All_B ...
# 6     462
# 9     457
# 1     402
# 3     354
# 7     351
# 11    330
# 4     324
# 0     299
# 12    279
# 5     261
# 2     246
# 8     245
# 13    232
# 14    230
# 10    132
# Name: count, dtype: int64

# %% [markdown]
# ### 5.5 Perform Spectral Clustering with Euclidean Distance

# %%
# Calling the function
Spectral_Euc_Clustering = Spectral_Euc(embedding_values,n_clusters)

# Transfer the result into dict
Spectral_Euc_result = dict(zip(list(embedding.keys()), Spectral_Euc_Clustering))
print("Spectral_Euc Cluster labels:")
print(Spectral_Euc_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Spectral_Euc_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Spectral_Euc.pkl', 'wb') as f:
    pickle.dump(Spectral_Euc_result, f)
# Out:
# Spectral_Euc Cluster labels:
# {'%C3%81ed%C3%A1n_mac_Gabr%C3%A1in': 14, '%C3%85land': 6, '%C3%89douard_Manet': 4, '%C3%89ire': 3, '%C3%93engus_I_of_the_Picts': 14, '%E2%82%AC2_commemorative_coins': 6, '10th_century': 4, '11th_century': 4, '12th_century': 4, '13th_century': 14, '14th_century': 4, '15th_century': 4, '15th_Marine_Expeditionary_Unit': 8, '16th_century': 4, '16_Cygni': 0, '16_Cygni_Bb': 0, '1755_Lisbon_earthquake': 12, '17th_century': 6, '1896_Summer_Olympics': 14, '18th_century': 6, '1928_Okeechobee_Hurricane': 12, '1973_oil_crisis': 6, '1980_eruption_of_Mount_St._Helens': 12, '1997_Pacific_hurricane_season': 12, '19th_century': 6, '1st_century': 14, '1st_century_BC': 14, '1_Ceres': 0, '2-6-0': 7, '2-8-0': 7, '2003_Atlantic_hurricane_season': 12, '2004_Atlantic_hurricane_season': 12, '2004_Indian_Ocean_earthquake': 12, '2005_Atlantic_hurricane_season': 12, '2005_Hertfordshire_Oil_Storage_Terminal_fire': 12, '2005_Kashmir_earthquake': 12, '2005_Lake_Tanganyika_earthquake': 12, '2005_Sumatra_earthquake': 12, '20th_century': 6, '21st_century': 6, '2nd_century': 14, '3rd_century': 14, '3_Juno': 0, '4-2-0': 7, '4-4-0': 7, '4-6-0': 7, '47_Ursae_Majoris': 0, '47_Ursae_Majoris_b': 0, '47_Ursae_Majoris_c': 0, '4th_century': 14, '4_Vesta': 0, '55_Cancri': 0, '55_Cancri_b': 0, '55_Cancri_c': 0, '55_Cancri_d': 0, '55_Cancri_e': 0, '5th_century': 14, '6-2-0': 7, '6th_century': 14, '7th_century': 14, '8th_century': 14, '90377_Sedna': 0, '9th_century': 14, 'A._E._J._Collins': 11, 'Aachen': 13, 'Aardvark': 1, 'Aarhus': 13, 'Abac%C3%A1': 2, 'Abacus': 14, 'Abadan': 14, 'Abbadid': 14, 'Abbasid': 14, 'Abbas_I_of_Persia': 14, 'Abbey': 4, 'Abbey_Theatre': 3, 'Abbot': 4, 'Abel_Tasman': 10, 'Aberdeen': 3, 'Aberration_of_light': 0, 'Aberystwyth': 3, 'Abhidhamma_Pitaka': 5, 'Abidjan': 13, 'Abkhazia': 6, 'Able_Archer_83': 6, 'ABO_blood_group_system': 8, 'Abraham_Goldfaden': 4, 'Abraham_Lincoln': 11, 'Absinthe': 2, 'Absolute_zero': 0, 'Abstract_art': 5, 'Abuja': 13, 'Abu_Dhabi': 13, 'Acceleration': 5, 'Accountancy': 5, 'Accra': 13, 'Acetic_acid': 2, 'Acetone': 2, 'Achilles': 14, 'Achilles_tendon': 14, 'Acid_rain': 12, 'Acorn_Computers': 8, 'Actinium': 9, 'Action_potential': 12, 'Actor': 8, 'Acts_of_Union_1707': 3, 'Actuary': 5, 'AC_DC': 8, 'Adam_Smith': 11, 'Addis_Ababa': 13, 'Adelaide': 13, 'Adenosine_triphosphate': 0, 'Adi_Shankara': 5, 'Adolf_Hitler': 11, 'Adriaen_van_der_Donck': 10, 'Advertising': 14, 'Aesthetics': 5, 'Afghanistan': 6, 'Afghan_Hound': 1, 'Africa': 14, 'African_American_literature': 8, 'African_Black_Oystercatcher': 1, 'African_Brush-tailed_Porcupine': 1, 'African_Buffalo': 1, 'African_clawed_frog': 1, 'African_Darter': 1, 'African_dwarf_frog': 1, 'African_Great_Lakes': 13, 'African_Grey_Hornbill': 1, 'African_Grey_Parrot': 1, 'African_Jacana': 1, 'African_Penguin': 1, 'African_slave_trade': 10, 'African_Union': 6, 'African_Wild_Dog': 1, 'Afrikaans': 13, 'Agamemnon': 14, 'Age_of_Enlightenment': 5, 'Aggregator': 8, 'Agnosticism': 5, 'Agriculture': 5, 'AIDS': 8, 'Airbus': 8, 'Airbus_A380': 13, 'Aircraft': 8, 'Aircraft_carrier': 8, 'Airship': 8, 'Ajax_%28programming%29': 8, 'AK-47': 6, 'Akbar': 14, 'Akhenaten': 14, 'Akira_Kurosawa': 8, 'Akkadian_Empire': 14, 'Akrotiri_and_Dhekelia': 10, 'Aksumite_currency': 14, 'Alamosaurus': 1, 'Alan_Turing': 11, 'Albania': 14, 'Albatross': 1, 'Albertosaurus': 1, 'Alberto_Santos-Dumont': 4, 'Albert_Einstein': 11, 'Albigensian_Crusade': 4, 'Albinism': 2, 'Albrecht_D%C3%BCrer': 4, 'Albrecht_Rodenbach': 4, 'Alchemy': 9, 'Alcibiades': 14, 'Alcohol': 2, 'ALCO_FA': 7, 'Aleksandr_Pushkin': 11, 'Aleksandr_Vasilevsky': 11, 'Aleksey_Arakcheyev': 11, 'Alexander_Graham_Bell': 11, 'Alexander_Hamilton': 11, 'Alexander_the_Great': 14, 'Alfred_Hitchcock': 11, 'Alfred_Nobel': 11, 'Alfred_the_Great': 3, 'Algebra': 5, 'Algeria': 10, 'Algerian_Civil_War': 6, 'Algiers': 13, 'Algol': 0, 'Algoma_Central_Railway': 7, 'Algorithm': 5, 'Alice%27s_Adventures_in_Wonderland': 3, 'Allah': 14, 'Allegory_in_the_Middle_Ages': 4, 'Alligator': 1, 'Allitera ...
# 8     604
# 1     412
# 11    390
# 5     354
# 6     333
# 3     324
# 14    285
# 12    277
# 2     274
# 10    263
# 13    260
# 4     257
# 7     213
# 9     201
# 0     157
# Name: count, dtype: int64

# %% [markdown]
# ### 5.6 Perform Spectral Clustering with Cosine Similarity

# %%
# Calling the function
Spectral_Cos_Clustering = Spectral_Cos(embedding_values,n_clusters)

# Transfer the result into dict
Spectral_Cos_result = dict(zip(list(embedding.keys()), Spectral_Cos_Clustering))
print("Spectral_Euc Cluster labels:")
print(Spectral_Cos_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Spectral_Cos_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Spectral_Cos.pkl', 'wb') as f:
    pickle.dump(Spectral_Cos_result, f)
# Out:
# Spectral_Euc Cluster labels:
# {'%C3%81ed%C3%A1n_mac_Gabr%C3%A1in': 6, '%C3%85land': 2, '%C3%89douard_Manet': 0, '%C3%89ire': 9, '%C3%93engus_I_of_the_Picts': 6, '%E2%82%AC2_commemorative_coins': 5, '10th_century': 6, '11th_century': 6, '12th_century': 6, '13th_century': 6, '14th_century': 6, '15th_century': 6, '15th_Marine_Expeditionary_Unit': 5, '16th_century': 6, '16_Cygni': 12, '16_Cygni_Bb': 12, '1755_Lisbon_earthquake': 2, '17th_century': 13, '1896_Summer_Olympics': 6, '18th_century': 6, '1928_Okeechobee_Hurricane': 7, '1973_oil_crisis': 5, '1980_eruption_of_Mount_St._Helens': 7, '1997_Pacific_hurricane_season': 7, '19th_century': 2, '1st_century': 6, '1st_century_BC': 6, '1_Ceres': 12, '2-6-0': 8, '2-8-0': 8, '2003_Atlantic_hurricane_season': 7, '2004_Atlantic_hurricane_season': 7, '2004_Indian_Ocean_earthquake': 7, '2005_Atlantic_hurricane_season': 7, '2005_Hertfordshire_Oil_Storage_Terminal_fire': 8, '2005_Kashmir_earthquake': 14, '2005_Lake_Tanganyika_earthquake': 7, '2005_Sumatra_earthquake': 7, '20th_century': 13, '21st_century': 13, '2nd_century': 6, '3rd_century': 6, '3_Juno': 12, '4-2-0': 8, '4-4-0': 8, '4-6-0': 8, '47_Ursae_Majoris': 12, '47_Ursae_Majoris_b': 12, '47_Ursae_Majoris_c': 12, '4th_century': 6, '4_Vesta': 12, '55_Cancri': 12, '55_Cancri_b': 12, '55_Cancri_c': 12, '55_Cancri_d': 12, '55_Cancri_e': 12, '5th_century': 6, '6-2-0': 8, '6th_century': 6, '7th_century': 6, '8th_century': 6, '90377_Sedna': 12, '9th_century': 6, 'A._E._J._Collins': 11, 'Aachen': 14, 'Aardvark': 1, 'Aarhus': 14, 'Abac%C3%A1': 3, 'Abacus': 6, 'Abadan': 6, 'Abbadid': 6, 'Abbasid': 6, 'Abbas_I_of_Persia': 6, 'Abbey': 9, 'Abbey_Theatre': 9, 'Abbot': 6, 'Abel_Tasman': 2, 'Aberdeen': 9, 'Aberration_of_light': 12, 'Aberystwyth': 9, 'Abhidhamma_Pitaka': 13, 'Abidjan': 2, 'Abkhazia': 5, 'Able_Archer_83': 5, 'ABO_blood_group_system': 3, 'Abraham_Goldfaden': 0, 'Abraham_Lincoln': 11, 'Absinthe': 3, 'Absolute_zero': 12, 'Abstract_art': 13, 'Abuja': 14, 'Abu_Dhabi': 14, 'Acceleration': 13, 'Accountancy': 13, 'Accra': 2, 'Acetic_acid': 3, 'Acetone': 10, 'Achilles': 6, 'Achilles_tendon': 6, 'Acid_rain': 3, 'Acorn_Computers': 13, 'Actinium': 10, 'Action_potential': 3, 'Actor': 4, 'Acts_of_Union_1707': 9, 'Actuary': 13, 'AC_DC': 4, 'Adam_Smith': 11, 'Addis_Ababa': 14, 'Adelaide': 14, 'Adenosine_triphosphate': 12, 'Adi_Shankara': 0, 'Adolf_Hitler': 5, 'Adriaen_van_der_Donck': 0, 'Advertising': 6, 'Aesthetics': 13, 'Afghanistan': 5, 'Afghan_Hound': 1, 'Africa': 2, 'African_American_literature': 13, 'African_Black_Oystercatcher': 1, 'African_Brush-tailed_Porcupine': 1, 'African_Buffalo': 1, 'African_clawed_frog': 1, 'African_Darter': 1, 'African_dwarf_frog': 1, 'African_Great_Lakes': 14, 'African_Grey_Hornbill': 1, 'African_Grey_Parrot': 1, 'African_Jacana': 1, 'African_Penguin': 1, 'African_slave_trade': 2, 'African_Union': 2, 'African_Wild_Dog': 1, 'Afrikaans': 14, 'Agamemnon': 6, 'Age_of_Enlightenment': 13, 'Aggregator': 13, 'Agnosticism': 13, 'Agriculture': 13, 'AIDS': 2, 'Airbus': 13, 'Airbus_A380': 14, 'Aircraft': 13, 'Aircraft_carrier': 8, 'Airship': 13, 'Ajax_%28programming%29': 13, 'AK-47': 5, 'Akbar': 6, 'Akhenaten': 6, 'Akira_Kurosawa': 4, 'Akkadian_Empire': 6, 'Akrotiri_and_Dhekelia': 2, 'Aksumite_currency': 6, 'Alamosaurus': 1, 'Alan_Turing': 0, 'Albania': 6, 'Albatross': 1, 'Albertosaurus': 1, 'Alberto_Santos-Dumont': 0, 'Albert_Einstein': 0, 'Albigensian_Crusade': 6, 'Albinism': 3, 'Albrecht_D%C3%BCrer': 0, 'Albrecht_Rodenbach': 0, 'Alchemy': 10, 'Alcibiades': 6, 'Alcohol': 3, 'ALCO_FA': 8, 'Aleksandr_Pushkin': 0, 'Aleksandr_Vasilevsky': 5, 'Aleksey_Arakcheyev': 0, 'Alexander_Graham_Bell': 0, 'Alexander_Hamilton': 11, 'Alexander_the_Great': 6, 'Alfred_Hitchcock': 0, 'Alfred_Nobel': 0, 'Alfred_the_Great': 9, 'Algebra': 13, 'Algeria': 2, 'Algerian_Civil_War': 5, 'Algiers': 2, 'Algol': 12, 'Algoma_Central_Railway': 8, 'Algorithm': 13, 'Alice%27s_Adventures_in_Wonderland': 0, 'Allah': 6, 'Allegory_in_the_Middle_Ages': 6, 'Alligator': 1, 'Alliterative_verse': 6, 'All ...
# 13    593
# 1     429
# 6     398
# 14    389
# 2     373
# 9     358
# 0     322
# 3     313
# 4     290
# 12    276
# 5     234
# 11    209
# 10    199
# 8     145
# 7      76
# Name: count, dtype: int64
