# %% [markdown]
# # CLUSTERING MODELS
#
# ### Clustering Workflow Overview:
# 1. **Define Clustering Methods**
#    Define functions for the following 5 clustering methods:
#    - K-Means
#    - K-Medoids
#    - K-Medoids
#    - Spectral Clustering
#
# 2. **Set Number of Clusters**
#    Calculate the number of original categories and set the clustering count to match this number.
#
# 3. **Execute Clustering and Save Results**
#    Perform clustering using each method and store results in dictionary format.
#    Save all clustering results as a pickle file in the directory `./output/clustering/`.

# %%
import pandas as pd
import numpy as np
import warnings
import os

warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1 K-MEANS

# %%
from sklearn.cluster import KMeans

def Kmeans_Raw(data,n_clusters,state=520):
    # Apply K-means clustering with 3 clusters
    kmeans = KMeans(n_clusters=n_clusters, random_state=state)
    kmeans.fit(data)

    return kmeans.labels_

# %% [markdown]
# ## 2 KMedoids (with distance matrix)
# - This method needs to use distance data

# %%
try:
    from sklearn_extra.cluster import KMedoids
except Exception as e:
    print('installing scikit-learn-extra package')
    
    # !pip install scikit-learn-extra
    
    from sklearn_extra.cluster import KMedoids

# %% [markdown]
# ### 2.1 Euclidean Distance

# %%
def Kmedoids_Euc(data,n_clusters,state=520):

    # Perform KMedoids
    kmedoids_euc = KMedoids(n_clusters=n_clusters, metric='euclidean', random_state=state)
    kmedoids_euc.fit(data)

    return kmedoids_euc.labels_

# %% [markdown]
# ### 2.2 Manhattan Distance

# %%
def Kmedoids_Man(data,n_clusters,state=520):

    # Perform KMedoids
    kmedoids_man = KMedoids(n_clusters=n_clusters, metric='manhattan',random_state=state)
    kmedoids_man.fit(data)

    return kmedoids_man.labels_

# %% [markdown]
# ### 2.3 Cosine Distance

# %%
def Kmedoids_Cos(data,n_clusters,state=520):

    # Perform KMedoids
    kmedoids_cos = KMedoids(n_clusters=n_clusters, metric='cosine',random_state=state)
    kmedoids_cos.fit(data)

    return kmedoids_cos.labels_

# %% [markdown]
# ## 3 Spectral Clustering (with similarity matrix)
# - This method needs to use similarity

# %%
from sklearn.cluster import SpectralClustering

# %% [markdown]
# ### 2.1 Nearest Neighbors

# %%
def Spectral_Nn(data,n_clusters,state=520):

    # Perform clustery
    spectral_nn = SpectralClustering(n_clusters=n_clusters, affinity='nearest_neighbors',random_state = state)
    spectral_nn_labels = spectral_nn.fit_predict(data)

    return spectral_nn_labels

# %% [markdown]
# ### 2.2 Radial Basis Function

# %%
def Spectral_Rbf(data,n_clusters,state=520):

    # Perform clustery
    spectral_rbf = SpectralClustering(n_clusters=n_clusters, affinity='rbf',random_state=state)
    spectral_rbf_labels = spectral_rbf.fit_predict(data)

    return spectral_rbf_labels

# %% [markdown]
# ## 4. Calculate the amount of original categories

# %%
# We need to keep the clustering number is equal to the amount of original categories
file_path = './/dataset//wikispeedia_paths-and-graph//categories.tsv'
category_df = pd.read_csv(file_path, sep='\t', skiprows=12,header=None)
category_df.columns = ['concept','category']

# %%
# the type of data is dict
print('The total number of articles in the category_dataset is: {}'.format(category_df.shape[0]))
# Out:
# The total number of articles in the category_dataset is: 5204

# %%
# Collect all primary categories
category_df['primary_category'] = category_df['category'].apply(lambda x: x.split('.')[1])
print('The orginal primary categories are:')
print(category_df['primary_category'].unique())

# Set the number of clustering
n_clusters = len(category_df['primary_category'].unique())
print('The clustering number we need to set is: {}'.format(n_clusters))
# Out:
# The orginal primary categories are:
# ['History' 'People' 'Countries' 'Geography' 'Business_Studies' 'Science'
#  'Everyday_life' 'Design_and_Technology' 'Music' 'IT'
#  'Language_and_literature' 'Mathematics' 'Religion' 'Art' 'Citizenship']
# The clustering number we need to set is: 15

# %% [markdown]
# ## 5. Perform Clustering and Save results

# %% [markdown]
# ### 5.1 Read the embedding data

# %%
import pickle

# Set the embedding file path
file_path = './/output//embeddings//all_mpnet_base_v2//20241109_150434//embeddings.pkl'
saved_path = './/output//clustering//all_mpnet_base_v2'

# Read the file and print embeddings
with open(file_path, 'rb') as file:
    embedding = pickle.load(file)
    embedding_values = list(embedding.values())

print('The total number of articles in the category_dataset is: {}'.format(len(embedding_values)))
# Out:
# The total number of articles in the category_dataset is: 4604

# %%
# Set the embedding file path

file_path = './/output//embeddings//all_MiniLM_L6_v2//20241109_104244//embeddings.pkl'
saved_path = './/output//clustering//all_MiniLM_L6_v2'

# Read the file and print embeddings
with open(file_path, 'rb') as file:
    embedding = pickle.load(file)
    embedding_values = list(embedding.values())

print('The total number of articles in the category_dataset is: {}'.format(len(embedding_values)))
# Out:
# The total number of articles in the category_dataset is: 5232

# %% [markdown]
# ### 5.2 Perform K-MEANS Clustering

# %%
# Calling the function
Kmeans_Clustering = Kmeans_Raw(embedding_values,n_clusters)

# Transfer the result into dict
Kmeans_result = dict(zip(list(embedding.keys()), Kmeans_Clustering))
print("K-means Cluster labels:")
print(Kmeans_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Kmeans_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//KMeans.pkl', 'wb') as f:
    pickle.dump(Kmeans_result, f)
# Out:
# K-means Cluster labels:
# {'Lilongwe': 2, 'West_Virginia': 10, 'Magnet': 8, 'Scrooge_McDuck': 1, 'Juniper_berry': 11, 'Gerald_Durrell': 4, 'Henry_IV_of_England': 4, 'Central_African_Republic': 2, 'Lebanon_A': 3, 'Avro_Lancaster': 1, 'Clifton_Suspension_Bridge': 6, 'Speech_synthesis': 7, 'Number': 7, 'James_Garfield': 4, 'Summer': 9, 'Indian_Standard_Time': 10, 'Religious_Society_of_Friends': 7, 'Iron_Maiden': 1, 'Gliese_876_c': 0, 'Ununoctium': 8, 'Military_history_of_the_Soviet_Union': 1, 'Rockall': 9, 'Engineering': 7, 'Butter': 11, 'Dune': 9, 'Myco-heterotrophy': 11, 'Maize': 11, 'Celtic_mythology': 6, 'Telephone_exchange': 7, 'Medal_of_Honor': 1, 'University_of_Texas_at_Austin': 1, 'Cyril_Clarke': 4, 'Rosetta_Stone': 12, 'Felix_Mendelssohn': 4, 'Jacobite_rising': 6, 'Paris': 10, 'West_Flemish': 10, 'Catholic_social_teaching': 12, 'Borage': 11, 'Demographics_of_Libya': 2, 'Creation-evolution_controversy': 7, 'Grand_Central_Station_%28Chicago%29': 1, 'Syria_Ep_News_270706': 3, 'Darmstadtium': 8, 'Syria_Ep_News_090806': 3, 'Treecreeper': 13, 'Utilitarianism': 7, 'Toronto': 10, 'Mary_II_of_England': 4, 'Isle_of_Wight': 6, 'French_language': 2, 'Raising_the_Flag_on_Iwo_Jima': 1, 'History_of_Buddhism': 12, 'Lake_Mead': 9, 'Edible_salt': 8, 'Isospin': 1, 'The_Waste_Land': 4, 'Working_poor': 7, 'Why_I_Will_Remember_This_Charity': 5, 'Sparrowhawk': 13, 'Tropical_Storm_Henri_%282003%29': 14, 'Corporate_finance': 7, 'Velociraptor': 13, 'Canadian_House_of_Commons': 6, 'Game_theory': 7, 'Textile': 7, 'Music_of_Ireland': 7, 'Bicycle_Thieves': 1, 'List_of_minerals': 8, 'Latin': 12, 'Color_Graphics_Adapter': 1, 'Tropical_cyclone': 14, 'Demographics_of_Ghana': 2, 'Helicobacter_pylori': 11, 'Black_Death': 12, 'Tansy': 11, 'James_Buchanan': 4, 'WorkChoices': 7, '18th_century': 4, 'Helium': 8, 'Quartz': 8, 'Irish_poetry': 6, 'Absolute_zero': 8, 'Stuttgart': 10, 'Tsunami': 9, 'Soil_salination': 9, 'Palladium': 8, 'Tom_and_Jerry_%28MGM%29': 1, 'Victoria_of_the_United_Kingdom': 4, 'Indira_Gandhi': 4, 'Atonality': 12, 'Denis_Law': 4, 'The_Iron_Bridge': 6, 'Laozi': 12, 'Dover': 6, 'George_II_of_Great_Britain': 4, 'The_Wall_Street_Journal': 1, 'Wars_of_the_Roses': 4, 'Extraterrestrial_life': 0, 'History_of_Singapore': 1, 'Zionism': 10, 'Cuckmere_Haven': 6, 'Genetics': 7, 'Channel_Islands': 6, 'Riyadh': 10, 'History_of_South_Africa_in_the_apartheid_era': 2, 'Child_Photo_18': 5, 'Croatia_A': 3, 'Radon': 8, 'Grange_Hill': 6, 'Martinique': 10, 'Jane_Fonda': 1, 'Syria_A': 3, 'Urial': 13, 'Wow_Hold_An_Event': 5, 'Computer': 7, 'Mars_Exploration_Rover': 1, 'Howland_Island': 14, 'Gerald_Ford': 4, 'Felice_Beato': 4, 'Fermium': 8, 'Gallimimus': 13, 'Arctic': 9, 'Bioinformatics': 7, 'Mega_Man_X_%28character%29': 1, 'Mosque': 7, 'Humbert_Roque_Versace': 1, 'Anton_Alexander_von_Werner': 4, 'Indian_Railways': 1, 'List_of_European_Union_member_states_by_accession': 10, 'Iraq_War': 3, 'Robert_Schumann': 4, 'Boy_Scout': 1, 'Clone_Wars_%28Star_Wars%29': 1, 'Cretaceous': 9, 'Cadmium': 8, 'Gray_reef_shark': 13, 'S-mine': 1, 'Roan_Antelope': 13, 'Brothers_Grimm': 4, 'Sean_Connery': 4, 'Google': 1, 'Boat': 7, 'Colditz_Castle': 1, 'Isaac_Asimov': 1, 'Casimir_effect': 7, 'Parasaurolophus': 13, '13th_century': 12, 'Southern_Pacific_4449': 1, 'Rapping': 7, 'Potassium_nitrate': 8, 'Hubbard_Glacier': 9, 'Equatorial_Guinea': 2, 'Plover': 13, 'Frog': 13, 'Kigo': 7, 'Osiris': 12, 'Ultraviolet': 8, 'Report_From_Chernobyl': 3, 'Polish-Muscovite_War_%281605%E2%80%931618%29': 12, 'Herbert_Hoover': 4, 'Currency': 7, 'Nutrition': 7, '%C3%89ire': 6, 'Ben_Jonson': 4, 'Oceania': 14, 'Solar_eclipse': 0, 'Almond': 11, 'A_To_Z_Fundraising': 5, 'Saudi_Arabia': 10, 'Contact_lens': 7, 'Cerium': 8, 'Uruguay': 14, 'GNU_Project': 7, 'Chile_A': 3, 'Aarhus': 10, 'Universe': 0, 'Horse': 13, 'Wow_Photo_Exhibition': 5, 'Nitrogen_fixation': 11, 'Onion_dome': 12, 'Ziad_Jarrah': 1, 'Americas': 5, 'Asteroid': 0, 'Music_of_Albania': 10, 'Scanian_%28linguistics%29': 10, 'Prostate_cancer': 10, 'Plate_tectonics': 9, 'Yttrium': 8, 'Lis ...
# 7     709
# 1     626
# 4     503
# 13    444
# 12    438
# 10    380
# 3     317
# 6     291
# 14    285
# 9     245
# 5     236
# 2     223
# 8     215
# 11    196
# 0     124
# Name: count, dtype: int64

# %% [markdown]
# ### 5.3 Perform K-Medoids Clustering with Euclidean Distance

# %%
# Calling the function
Kmedoids_Euc_Clustering = Kmedoids_Euc(embedding_values,n_clusters)

# Transfer the result into dict
Kmedoids_Euc_result = dict(zip(list(embedding.keys()), Kmedoids_Euc_Clustering))
print("Kmedoids_Euc Cluster labels:")
print(Kmedoids_Euc_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Kmedoids_Euc_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Kmedoids_Euc.pkl', 'wb') as f:
    pickle.dump(Kmedoids_Euc_result, f)
# Out:
# Kmedoids_Euc Cluster labels:
# {'Lilongwe': 11, 'West_Virginia': 5, 'Magnet': 9, 'Scrooge_McDuck': 10, 'Juniper_berry': 9, 'Gerald_Durrell': 1, 'Henry_IV_of_England': 14, 'Central_African_Republic': 6, 'Lebanon_A': 10, 'Avro_Lancaster': 7, 'Clifton_Suspension_Bridge': 10, 'Speech_synthesis': 9, 'Number': 7, 'James_Garfield': 11, 'Summer': 1, 'Indian_Standard_Time': 7, 'Religious_Society_of_Friends': 13, 'Iron_Maiden': 14, 'Gliese_876_c': 5, 'Ununoctium': 7, 'Military_history_of_the_Soviet_Union': 7, 'Rockall': 1, 'Engineering': 8, 'Butter': 6, 'Dune': 9, 'Myco-heterotrophy': 7, 'Maize': 6, 'Celtic_mythology': 7, 'Telephone_exchange': 5, 'Medal_of_Honor': 6, 'University_of_Texas_at_Austin': 6, 'Cyril_Clarke': 10, 'Rosetta_Stone': 7, 'Felix_Mendelssohn': 10, 'Jacobite_rising': 1, 'Paris': 6, 'West_Flemish': 14, 'Catholic_social_teaching': 8, 'Borage': 9, 'Demographics_of_Libya': 6, 'Creation-evolution_controversy': 7, 'Grand_Central_Station_%28Chicago%29': 5, 'Syria_Ep_News_270706': 10, 'Darmstadtium': 7, 'Syria_Ep_News_090806': 10, 'Treecreeper': 10, 'Utilitarianism': 0, 'Toronto': 2, 'Mary_II_of_England': 5, 'Isle_of_Wight': 0, 'French_language': 5, 'Raising_the_Flag_on_Iwo_Jima': 12, 'History_of_Buddhism': 7, 'Lake_Mead': 7, 'Edible_salt': 9, 'Isospin': 7, 'The_Waste_Land': 7, 'Working_poor': 11, 'Why_I_Will_Remember_This_Charity': 10, 'Sparrowhawk': 1, 'Tropical_Storm_Henri_%282003%29': 5, 'Corporate_finance': 5, 'Velociraptor': 1, 'Canadian_House_of_Commons': 5, 'Game_theory': 0, 'Textile': 6, 'Music_of_Ireland': 1, 'Bicycle_Thieves': 12, 'List_of_minerals': 7, 'Latin': 1, 'Color_Graphics_Adapter': 1, 'Tropical_cyclone': 1, 'Demographics_of_Ghana': 3, 'Helicobacter_pylori': 1, 'Black_Death': 2, 'Tansy': 9, 'James_Buchanan': 3, 'WorkChoices': 13, '18th_century': 5, 'Helium': 7, 'Quartz': 6, 'Irish_poetry': 1, 'Absolute_zero': 7, 'Stuttgart': 6, 'Tsunami': 1, 'Soil_salination': 9, 'Palladium': 7, 'Tom_and_Jerry_%28MGM%29': 12, 'Victoria_of_the_United_Kingdom': 14, 'Indira_Gandhi': 7, 'Atonality': 8, 'Denis_Law': 14, 'The_Iron_Bridge': 7, 'Laozi': 1, 'Dover': 5, 'George_II_of_Great_Britain': 7, 'The_Wall_Street_Journal': 5, 'Wars_of_the_Roses': 7, 'Extraterrestrial_life': 1, 'History_of_Singapore': 5, 'Zionism': 7, 'Cuckmere_Haven': 0, 'Genetics': 12, 'Channel_Islands': 1, 'Riyadh': 7, 'History_of_South_Africa_in_the_apartheid_era': 14, 'Child_Photo_18': 12, 'Croatia_A': 13, 'Radon': 7, 'Grange_Hill': 3, 'Martinique': 1, 'Jane_Fonda': 12, 'Syria_A': 3, 'Urial': 0, 'Wow_Hold_An_Event': 13, 'Computer': 0, 'Mars_Exploration_Rover': 10, 'Howland_Island': 1, 'Gerald_Ford': 6, 'Felice_Beato': 12, 'Fermium': 7, 'Gallimimus': 6, 'Arctic': 7, 'Bioinformatics': 7, 'Mega_Man_X_%28character%29': 14, 'Mosque': 6, 'Humbert_Roque_Versace': 10, 'Anton_Alexander_von_Werner': 7, 'Indian_Railways': 9, 'List_of_European_Union_member_states_by_accession': 13, 'Iraq_War': 10, 'Robert_Schumann': 7, 'Boy_Scout': 10, 'Clone_Wars_%28Star_Wars%29': 5, 'Cretaceous': 5, 'Cadmium': 7, 'Gray_reef_shark': 1, 'S-mine': 14, 'Roan_Antelope': 14, 'Brothers_Grimm': 14, 'Sean_Connery': 1, 'Google': 7, 'Boat': 1, 'Colditz_Castle': 14, 'Isaac_Asimov': 8, 'Casimir_effect': 5, 'Parasaurolophus': 1, '13th_century': 7, 'Southern_Pacific_4449': 12, 'Rapping': 6, 'Potassium_nitrate': 3, 'Hubbard_Glacier': 7, 'Equatorial_Guinea': 5, 'Plover': 9, 'Frog': 1, 'Kigo': 14, 'Osiris': 7, 'Ultraviolet': 7, 'Report_From_Chernobyl': 13, 'Polish-Muscovite_War_%281605%E2%80%931618%29': 14, 'Herbert_Hoover': 14, 'Currency': 5, 'Nutrition': 9, '%C3%89ire': 1, 'Ben_Jonson': 7, 'Oceania': 5, 'Solar_eclipse': 7, 'Almond': 6, 'A_To_Z_Fundraising': 10, 'Saudi_Arabia': 7, 'Contact_lens': 12, 'Cerium': 7, 'Uruguay': 1, 'GNU_Project': 3, 'Chile_A': 12, 'Aarhus': 7, 'Universe': 4, 'Horse': 6, 'Wow_Photo_Exhibition': 12, 'Nitrogen_fixation': 5, 'Onion_dome': 7, 'Ziad_Jarrah': 14, 'Americas': 8, 'Asteroid': 6, 'Music_of_Albania': 14, 'Scanian_%28linguistics%29': 7, 'Prostate_cancer': 6, 'Plate_tectonics': 7, 'Yttrium': 8, 'List ...
# 7     1260
# 1      888
# 5      560
# 14     376
# 6      358
# 10     287
# 12     285
# 13     233
# 0      227
# 8      143
# 2      143
# 9      137
# 3      119
# 11     114
# 4      102
# Name: count, dtype: int64

# %% [markdown]
# ### 5.4 Perform K-Medoids Clustering with Manhattan Distance

# %%
# Calling the function
Kmedoids_Man_Clustering = Kmedoids_Man(embedding_values,n_clusters)

# Transfer the result into dict
Kmedoids_Man_result = dict(zip(list(embedding.keys()), Kmedoids_Man_Clustering))
print("Kmedoids_Man Cluster labels:")
print(Kmedoids_Man_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Kmedoids_Man_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Kmedoids_Man.pkl', 'wb') as f:
    pickle.dump(Kmedoids_Man_result, f)
# Out:
# Kmedoids_Man Cluster labels:
# {'Lilongwe': 9, 'West_Virginia': 0, 'Magnet': 10, 'Scrooge_McDuck': 5, 'Juniper_berry': 13, 'Gerald_Durrell': 11, 'Henry_IV_of_England': 3, 'Central_African_Republic': 9, 'Lebanon_A': 1, 'Avro_Lancaster': 9, 'Clifton_Suspension_Bridge': 0, 'Speech_synthesis': 12, 'Number': 9, 'James_Garfield': 8, 'Summer': 4, 'Indian_Standard_Time': 8, 'Religious_Society_of_Friends': 10, 'Iron_Maiden': 9, 'Gliese_876_c': 2, 'Ununoctium': 3, 'Military_history_of_the_Soviet_Union': 9, 'Rockall': 4, 'Engineering': 1, 'Butter': 9, 'Dune': 2, 'Myco-heterotrophy': 3, 'Maize': 9, 'Celtic_mythology': 9, 'Telephone_exchange': 2, 'Medal_of_Honor': 12, 'University_of_Texas_at_Austin': 8, 'Cyril_Clarke': 7, 'Rosetta_Stone': 14, 'Felix_Mendelssohn': 9, 'Jacobite_rising': 9, 'Paris': 0, 'West_Flemish': 0, 'Catholic_social_teaching': 10, 'Borage': 8, 'Demographics_of_Libya': 14, 'Creation-evolution_controversy': 9, 'Grand_Central_Station_%28Chicago%29': 9, 'Syria_Ep_News_270706': 12, 'Darmstadtium': 3, 'Syria_Ep_News_090806': 12, 'Treecreeper': 7, 'Utilitarianism': 4, 'Toronto': 10, 'Mary_II_of_England': 5, 'Isle_of_Wight': 4, 'French_language': 9, 'Raising_the_Flag_on_Iwo_Jima': 4, 'History_of_Buddhism': 9, 'Lake_Mead': 4, 'Edible_salt': 9, 'Isospin': 3, 'The_Waste_Land': 3, 'Working_poor': 13, 'Why_I_Will_Remember_This_Charity': 3, 'Sparrowhawk': 4, 'Tropical_Storm_Henri_%282003%29': 0, 'Corporate_finance': 9, 'Velociraptor': 9, 'Canadian_House_of_Commons': 9, 'Game_theory': 6, 'Textile': 9, 'Music_of_Ireland': 9, 'Bicycle_Thieves': 11, 'List_of_minerals': 2, 'Latin': 9, 'Color_Graphics_Adapter': 8, 'Tropical_cyclone': 4, 'Demographics_of_Ghana': 8, 'Helicobacter_pylori': 9, 'Black_Death': 0, 'Tansy': 11, 'James_Buchanan': 0, 'WorkChoices': 6, '18th_century': 9, 'Helium': 3, 'Quartz': 2, 'Irish_poetry': 9, 'Absolute_zero': 8, 'Stuttgart': 8, 'Tsunami': 4, 'Soil_salination': 0, 'Palladium': 2, 'Tom_and_Jerry_%28MGM%29': 9, 'Victoria_of_the_United_Kingdom': 9, 'Indira_Gandhi': 1, 'Atonality': 11, 'Denis_Law': 4, 'The_Iron_Bridge': 5, 'Laozi': 9, 'Dover': 5, 'George_II_of_Great_Britain': 14, 'The_Wall_Street_Journal': 5, 'Wars_of_the_Roses': 5, 'Extraterrestrial_life': 4, 'History_of_Singapore': 0, 'Zionism': 9, 'Cuckmere_Haven': 4, 'Genetics': 11, 'Channel_Islands': 9, 'Riyadh': 14, 'History_of_South_Africa_in_the_apartheid_era': 9, 'Child_Photo_18': 11, 'Croatia_A': 10, 'Radon': 0, 'Grange_Hill': 12, 'Martinique': 8, 'Jane_Fonda': 3, 'Syria_A': 8, 'Urial': 4, 'Wow_Hold_An_Event': 4, 'Computer': 4, 'Mars_Exploration_Rover': 14, 'Howland_Island': 4, 'Gerald_Ford': 9, 'Felice_Beato': 11, 'Fermium': 9, 'Gallimimus': 11, 'Arctic': 4, 'Bioinformatics': 2, 'Mega_Man_X_%28character%29': 9, 'Mosque': 1, 'Humbert_Roque_Versace': 12, 'Anton_Alexander_von_Werner': 6, 'Indian_Railways': 10, 'List_of_European_Union_member_states_by_accession': 10, 'Iraq_War': 12, 'Robert_Schumann': 11, 'Boy_Scout': 12, 'Clone_Wars_%28Star_Wars%29': 12, 'Cretaceous': 9, 'Cadmium': 14, 'Gray_reef_shark': 4, 'S-mine': 12, 'Roan_Antelope': 4, 'Brothers_Grimm': 10, 'Sean_Connery': 5, 'Google': 4, 'Boat': 4, 'Colditz_Castle': 12, 'Isaac_Asimov': 6, 'Casimir_effect': 0, 'Parasaurolophus': 4, '13th_century': 9, 'Southern_Pacific_4449': 11, 'Rapping': 9, 'Potassium_nitrate': 8, 'Hubbard_Glacier': 4, 'Equatorial_Guinea': 9, 'Plover': 4, 'Frog': 9, 'Kigo': 12, 'Osiris': 9, 'Ultraviolet': 3, 'Report_From_Chernobyl': 10, 'Polish-Muscovite_War_%281605%E2%80%931618%29': 9, 'Herbert_Hoover': 9, 'Currency': 0, 'Nutrition': 4, '%C3%89ire': 9, 'Ben_Jonson': 9, 'Oceania': 9, 'Solar_eclipse': 14, 'Almond': 3, 'A_To_Z_Fundraising': 5, 'Saudi_Arabia': 14, 'Contact_lens': 0, 'Cerium': 3, 'Uruguay': 9, 'GNU_Project': 6, 'Chile_A': 10, 'Aarhus': 14, 'Universe': 9, 'Horse': 8, 'Wow_Photo_Exhibition': 11, 'Nitrogen_fixation': 9, 'Onion_dome': 11, 'Ziad_Jarrah': 12, 'Americas': 7, 'Asteroid': 7, 'Music_of_Albania': 9, 'Scanian_%28linguistics%29': 9, 'Prostate_cancer': 4, 'Plate_tectonics': 3, 'Yttrium': 11, 'List_of ...
# 9     1340
# 4      697
# 11     389
# 0      380
# 5      352
# 3      307
# 14     254
# 12     242
# 2      228
# 8      221
# 1      190
# 10     189
# 6      172
# 13     147
# 7      124
# Name: count, dtype: int64

# %% [markdown]
# ### 5.5 Perform K-Medoids Clustering with Cosine Distance

# %%
# Calling the function
Kmedoids_Cos_Clustering = Kmedoids_Cos(embedding_values,n_clusters)

# Transfer the result into dict
Kmedoids_Cos_result = dict(zip(list(embedding.keys()), Kmedoids_Cos_Clustering))
print("Kmedoids_Cos Cluster labels:")
print(Kmedoids_Cos_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Kmedoids_Cos_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Kmedoids_Cos.pkl', 'wb') as f:
    pickle.dump(Kmedoids_Cos_result, f)
# Out:
# Kmedoids_Cos Cluster labels:
# {'Lilongwe': 10, 'West_Virginia': 1, 'Magnet': 5, 'Scrooge_McDuck': 11, 'Juniper_berry': 11, 'Gerald_Durrell': 11, 'Henry_IV_of_England': 4, 'Central_African_Republic': 8, 'Lebanon_A': 6, 'Avro_Lancaster': 7, 'Clifton_Suspension_Bridge': 5, 'Speech_synthesis': 12, 'Number': 12, 'James_Garfield': 11, 'Summer': 2, 'Indian_Standard_Time': 7, 'Religious_Society_of_Friends': 1, 'Iron_Maiden': 4, 'Gliese_876_c': 11, 'Ununoctium': 7, 'Military_history_of_the_Soviet_Union': 7, 'Rockall': 2, 'Engineering': 12, 'Butter': 8, 'Dune': 12, 'Myco-heterotrophy': 11, 'Maize': 8, 'Celtic_mythology': 9, 'Telephone_exchange': 12, 'Medal_of_Honor': 11, 'University_of_Texas_at_Austin': 12, 'Cyril_Clarke': 11, 'Rosetta_Stone': 7, 'Felix_Mendelssohn': 10, 'Jacobite_rising': 9, 'Paris': 8, 'West_Flemish': 1, 'Catholic_social_teaching': 5, 'Borage': 12, 'Demographics_of_Libya': 9, 'Creation-evolution_controversy': 12, 'Grand_Central_Station_%28Chicago%29': 12, 'Syria_Ep_News_270706': 6, 'Darmstadtium': 7, 'Syria_Ep_News_090806': 5, 'Treecreeper': 11, 'Utilitarianism': 0, 'Toronto': 13, 'Mary_II_of_England': 3, 'Isle_of_Wight': 0, 'French_language': 3, 'Raising_the_Flag_on_Iwo_Jima': 0, 'History_of_Buddhism': 7, 'Lake_Mead': 12, 'Edible_salt': 12, 'Isospin': 11, 'The_Waste_Land': 12, 'Working_poor': 14, 'Why_I_Will_Remember_This_Charity': 5, 'Sparrowhawk': 11, 'Tropical_Storm_Henri_%282003%29': 3, 'Corporate_finance': 10, 'Velociraptor': 11, 'Canadian_House_of_Commons': 3, 'Game_theory': 1, 'Textile': 12, 'Music_of_Ireland': 9, 'Bicycle_Thieves': 14, 'List_of_minerals': 11, 'Latin': 2, 'Color_Graphics_Adapter': 2, 'Tropical_cyclone': 2, 'Demographics_of_Ghana': 6, 'Helicobacter_pylori': 11, 'Black_Death': 13, 'Tansy': 11, 'James_Buchanan': 6, 'WorkChoices': 11, '18th_century': 3, 'Helium': 7, 'Quartz': 8, 'Irish_poetry': 2, 'Absolute_zero': 11, 'Stuttgart': 8, 'Tsunami': 2, 'Soil_salination': 12, 'Palladium': 1, 'Tom_and_Jerry_%28MGM%29': 12, 'Victoria_of_the_United_Kingdom': 4, 'Indira_Gandhi': 12, 'Atonality': 12, 'Denis_Law': 4, 'The_Iron_Bridge': 7, 'Laozi': 10, 'Dover': 3, 'George_II_of_Great_Britain': 7, 'The_Wall_Street_Journal': 5, 'Wars_of_the_Roses': 7, 'Extraterrestrial_life': 11, 'History_of_Singapore': 3, 'Zionism': 12, 'Cuckmere_Haven': 9, 'Genetics': 11, 'Channel_Islands': 1, 'Riyadh': 7, 'History_of_South_Africa_in_the_apartheid_era': 4, 'Child_Photo_18': 5, 'Croatia_A': 14, 'Radon': 7, 'Grange_Hill': 6, 'Martinique': 2, 'Jane_Fonda': 1, 'Syria_A': 6, 'Urial': 11, 'Wow_Hold_An_Event': 5, 'Computer': 0, 'Mars_Exploration_Rover': 5, 'Howland_Island': 1, 'Gerald_Ford': 1, 'Felice_Beato': 4, 'Fermium': 7, 'Gallimimus': 11, 'Arctic': 7, 'Bioinformatics': 7, 'Mega_Man_X_%28character%29': 4, 'Mosque': 8, 'Humbert_Roque_Versace': 1, 'Anton_Alexander_von_Werner': 12, 'Indian_Railways': 6, 'List_of_European_Union_member_states_by_accession': 1, 'Iraq_War': 5, 'Robert_Schumann': 12, 'Boy_Scout': 5, 'Clone_Wars_%28Star_Wars%29': 3, 'Cretaceous': 12, 'Cadmium': 7, 'Gray_reef_shark': 9, 'S-mine': 4, 'Roan_Antelope': 11, 'Brothers_Grimm': 4, 'Sean_Connery': 11, 'Google': 12, 'Boat': 9, 'Colditz_Castle': 4, 'Isaac_Asimov': 12, 'Casimir_effect': 11, 'Parasaurolophus': 11, '13th_century': 7, 'Southern_Pacific_4449': 1, 'Rapping': 8, 'Potassium_nitrate': 12, 'Hubbard_Glacier': 7, 'Equatorial_Guinea': 3, 'Plover': 11, 'Frog': 11, 'Kigo': 12, 'Osiris': 7, 'Ultraviolet': 11, 'Report_From_Chernobyl': 14, 'Polish-Muscovite_War_%281605%E2%80%931618%29': 12, 'Herbert_Hoover': 4, 'Currency': 3, 'Nutrition': 2, '%C3%89ire': 2, 'Ben_Jonson': 11, 'Oceania': 1, 'Solar_eclipse': 12, 'Almond': 11, 'A_To_Z_Fundraising': 5, 'Saudi_Arabia': 7, 'Contact_lens': 11, 'Cerium': 12, 'Uruguay': 2, 'GNU_Project': 6, 'Chile_A': 14, 'Aarhus': 7, 'Universe': 1, 'Horse': 11, 'Wow_Photo_Exhibition': 5, 'Nitrogen_fixation': 3, 'Onion_dome': 7, 'Ziad_Jarrah': 4, 'Americas': 5, 'Asteroid': 11, 'Music_of_Albania': 4, 'Scanian_%28linguistics%29': 9, 'Prostate_cancer': 8, 'Plate_tectonics':  ...
# 12    812
# 11    722
# 7     674
# 5     506
# 1     375
# 3     317
# 2     310
# 4     241
# 9     238
# 8     219
# 6     183
# 0     182
# 10    168
# 13    160
# 14    125
# Name: count, dtype: int64

# %% [markdown]
# ### 5.6 Perform Spectral Clustering with Nearest Neighbors

# %%
# Calling the function
Spectral_Nn_Clustering = Spectral_Nn(embedding_values,n_clusters)

# Transfer the result into dict
Spectral_Nn_result = dict(zip(list(embedding.keys()), Spectral_Nn_Clustering))
print("Spectral_Nn Cluster labels:")
print(Spectral_Nn_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Spectral_Nn_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Spectral_Nn.pkl', 'wb') as f:
    pickle.dump(Spectral_Nn_result, f)
# Out:
# Spectral_Nn Cluster labels:
# {'Lilongwe': 14, 'West_Virginia': 1, 'Magnet': 6, 'Scrooge_McDuck': 3, 'Juniper_berry': 2, 'Gerald_Durrell': 3, 'Henry_IV_of_England': 3, 'Central_African_Republic': 14, 'Lebanon_A': 12, 'Avro_Lancaster': 3, 'Clifton_Suspension_Bridge': 1, 'Speech_synthesis': 13, 'Number': 13, 'James_Garfield': 1, 'Summer': 14, 'Indian_Standard_Time': 14, 'Religious_Society_of_Friends': 3, 'Iron_Maiden': 10, 'Gliese_876_c': 9, 'Ununoctium': 6, 'Military_history_of_the_Soviet_Union': 3, 'Rockall': 14, 'Engineering': 13, 'Butter': 2, 'Dune': 14, 'Myco-heterotrophy': 2, 'Maize': 2, 'Celtic_mythology': 3, 'Telephone_exchange': 13, 'Medal_of_Honor': 3, 'University_of_Texas_at_Austin': 14, 'Cyril_Clarke': 3, 'Rosetta_Stone': 3, 'Felix_Mendelssohn': 3, 'Jacobite_rising': 3, 'Paris': 14, 'West_Flemish': 14, 'Catholic_social_teaching': 3, 'Borage': 2, 'Demographics_of_Libya': 14, 'Creation-evolution_controversy': 3, 'Grand_Central_Station_%28Chicago%29': 1, 'Syria_Ep_News_270706': 12, 'Darmstadtium': 6, 'Syria_Ep_News_090806': 12, 'Treecreeper': 5, 'Utilitarianism': 3, 'Toronto': 14, 'Mary_II_of_England': 3, 'Isle_of_Wight': 14, 'French_language': 14, 'Raising_the_Flag_on_Iwo_Jima': 3, 'History_of_Buddhism': 3, 'Lake_Mead': 14, 'Edible_salt': 6, 'Isospin': 6, 'The_Waste_Land': 3, 'Working_poor': 3, 'Why_I_Will_Remember_This_Charity': 12, 'Sparrowhawk': 5, 'Tropical_Storm_Henri_%282003%29': 0, 'Corporate_finance': 3, 'Velociraptor': 11, 'Canadian_House_of_Commons': 3, 'Game_theory': 3, 'Textile': 3, 'Music_of_Ireland': 10, 'Bicycle_Thieves': 3, 'List_of_minerals': 6, 'Latin': 3, 'Color_Graphics_Adapter': 13, 'Tropical_cyclone': 0, 'Demographics_of_Ghana': 14, 'Helicobacter_pylori': 3, 'Black_Death': 3, 'Tansy': 2, 'James_Buchanan': 1, 'WorkChoices': 3, '18th_century': 3, 'Helium': 6, 'Quartz': 6, 'Irish_poetry': 3, 'Absolute_zero': 6, 'Stuttgart': 3, 'Tsunami': 14, 'Soil_salination': 14, 'Palladium': 6, 'Tom_and_Jerry_%28MGM%29': 3, 'Victoria_of_the_United_Kingdom': 3, 'Indira_Gandhi': 3, 'Atonality': 3, 'Denis_Law': 7, 'The_Iron_Bridge': 1, 'Laozi': 3, 'Dover': 14, 'George_II_of_Great_Britain': 3, 'The_Wall_Street_Journal': 13, 'Wars_of_the_Roses': 3, 'Extraterrestrial_life': 9, 'History_of_Singapore': 14, 'Zionism': 3, 'Cuckmere_Haven': 14, 'Genetics': 3, 'Channel_Islands': 14, 'Riyadh': 14, 'History_of_South_Africa_in_the_apartheid_era': 14, 'Child_Photo_18': 4, 'Croatia_A': 12, 'Radon': 6, 'Grange_Hill': 3, 'Martinique': 14, 'Jane_Fonda': 3, 'Syria_A': 12, 'Urial': 5, 'Wow_Hold_An_Event': 12, 'Computer': 13, 'Mars_Exploration_Rover': 3, 'Howland_Island': 14, 'Gerald_Ford': 1, 'Felice_Beato': 3, 'Fermium': 6, 'Gallimimus': 11, 'Arctic': 14, 'Bioinformatics': 13, 'Mega_Man_X_%28character%29': 13, 'Mosque': 3, 'Humbert_Roque_Versace': 3, 'Anton_Alexander_von_Werner': 3, 'Indian_Railways': 1, 'List_of_European_Union_member_states_by_accession': 14, 'Iraq_War': 12, 'Robert_Schumann': 3, 'Boy_Scout': 3, 'Clone_Wars_%28Star_Wars%29': 3, 'Cretaceous': 11, 'Cadmium': 6, 'Gray_reef_shark': 5, 'S-mine': 3, 'Roan_Antelope': 5, 'Brothers_Grimm': 3, 'Sean_Connery': 3, 'Google': 13, 'Boat': 3, 'Colditz_Castle': 3, 'Isaac_Asimov': 3, 'Casimir_effect': 13, 'Parasaurolophus': 11, '13th_century': 3, 'Southern_Pacific_4449': 1, 'Rapping': 10, 'Potassium_nitrate': 6, 'Hubbard_Glacier': 14, 'Equatorial_Guinea': 14, 'Plover': 5, 'Frog': 5, 'Kigo': 3, 'Osiris': 3, 'Ultraviolet': 3, 'Report_From_Chernobyl': 12, 'Polish-Muscovite_War_%281605%E2%80%931618%29': 3, 'Herbert_Hoover': 1, 'Currency': 3, 'Nutrition': 3, '%C3%89ire': 14, 'Ben_Jonson': 3, 'Oceania': 14, 'Solar_eclipse': 9, 'Almond': 2, 'A_To_Z_Fundraising': 12, 'Saudi_Arabia': 14, 'Contact_lens': 13, 'Cerium': 6, 'Uruguay': 14, 'GNU_Project': 13, 'Chile_A': 14, 'Aarhus': 14, 'Universe': 9, 'Horse': 5, 'Wow_Photo_Exhibition': 4, 'Nitrogen_fixation': 6, 'Onion_dome': 3, 'Ziad_Jarrah': 3, 'Americas': 12, 'Asteroid': 9, 'Music_of_Albania': 3, 'Scanian_%28linguistics%29': 14, 'Prostate_cancer': 3, 'Plate_tectonics': 14, ' ...
# 3     1936
# 14    1066
# 12     443
# 5      363
# 13     279
# 6      215
# 1      204
# 2      171
# 9      111
# 8       93
# 11      92
# 10      78
# 4       69
# 0       58
# 7       54
# Name: count, dtype: int64

# %% [markdown]
# ### 5.7 Perform Spectral Clustering with RBF

# %%
# Calling the function
Spectral_Rbf_Clustering = Spectral_Rbf(embedding_values,n_clusters)

# Transfer the result into dict
Spectral_Rbf_result = dict(zip(list(embedding.keys()), Spectral_Rbf_Clustering))
print("Spectral_Rbf Cluster labels:")
print(Spectral_Rbf_result)

# Calculate the counts of clustering results
value_counts = pd.Series(list(Spectral_Rbf_result.values())).value_counts()
print(value_counts)

# Save the clustering result
os.makedirs(saved_path, exist_ok=True)

with open(saved_path+'//Spectral_Rbf.pkl', 'wb') as f:
    pickle.dump(Spectral_Rbf_result, f)
# Out:
# Spectral_Rbf Cluster labels:
# {'Lilongwe': 11, 'West_Virginia': 10, 'Magnet': 3, 'Scrooge_McDuck': 12, 'Juniper_berry': 5, 'Gerald_Durrell': 8, 'Henry_IV_of_England': 8, 'Central_African_Republic': 11, 'Lebanon_A': 4, 'Avro_Lancaster': 8, 'Clifton_Suspension_Bridge': 10, 'Speech_synthesis': 9, 'Number': 9, 'James_Garfield': 12, 'Summer': 1, 'Indian_Standard_Time': 13, 'Religious_Society_of_Friends': 9, 'Iron_Maiden': 12, 'Gliese_876_c': 7, 'Ununoctium': 3, 'Military_history_of_the_Soviet_Union': 0, 'Rockall': 10, 'Engineering': 9, 'Butter': 9, 'Dune': 10, 'Myco-heterotrophy': 9, 'Maize': 9, 'Celtic_mythology': 8, 'Telephone_exchange': 9, 'Medal_of_Honor': 12, 'University_of_Texas_at_Austin': 12, 'Cyril_Clarke': 12, 'Rosetta_Stone': 2, 'Felix_Mendelssohn': 2, 'Jacobite_rising': 8, 'Paris': 10, 'West_Flemish': 0, 'Catholic_social_teaching': 2, 'Borage': 5, 'Demographics_of_Libya': 11, 'Creation-evolution_controversy': 9, 'Grand_Central_Station_%28Chicago%29': 12, 'Syria_Ep_News_270706': 1, 'Darmstadtium': 3, 'Syria_Ep_News_090806': 4, 'Treecreeper': 5, 'Utilitarianism': 9, 'Toronto': 6, 'Mary_II_of_England': 8, 'Isle_of_Wight': 10, 'French_language': 0, 'Raising_the_Flag_on_Iwo_Jima': 12, 'History_of_Buddhism': 13, 'Lake_Mead': 10, 'Edible_salt': 3, 'Isospin': 12, 'The_Waste_Land': 2, 'Working_poor': 9, 'Why_I_Will_Remember_This_Charity': 4, 'Sparrowhawk': 5, 'Tropical_Storm_Henri_%282003%29': 1, 'Corporate_finance': 9, 'Velociraptor': 14, 'Canadian_House_of_Commons': 8, 'Game_theory': 9, 'Textile': 9, 'Music_of_Ireland': 9, 'Bicycle_Thieves': 2, 'List_of_minerals': 3, 'Latin': 2, 'Color_Graphics_Adapter': 12, 'Tropical_cyclone': 1, 'Demographics_of_Ghana': 11, 'Helicobacter_pylori': 12, 'Black_Death': 2, 'Tansy': 5, 'James_Buchanan': 8, 'WorkChoices': 9, '18th_century': 8, 'Helium': 3, 'Quartz': 3, 'Irish_poetry': 2, 'Absolute_zero': 12, 'Stuttgart': 0, 'Tsunami': 1, 'Soil_salination': 13, 'Palladium': 3, 'Tom_and_Jerry_%28MGM%29': 12, 'Victoria_of_the_United_Kingdom': 8, 'Indira_Gandhi': 13, 'Atonality': 2, 'Denis_Law': 8, 'The_Iron_Bridge': 10, 'Laozi': 13, 'Dover': 10, 'George_II_of_Great_Britain': 8, 'The_Wall_Street_Journal': 12, 'Wars_of_the_Roses': 8, 'Extraterrestrial_life': 7, 'History_of_Singapore': 13, 'Zionism': 13, 'Cuckmere_Haven': 10, 'Genetics': 9, 'Channel_Islands': 10, 'Riyadh': 13, 'History_of_South_Africa_in_the_apartheid_era': 11, 'Child_Photo_18': 4, 'Croatia_A': 0, 'Radon': 3, 'Grange_Hill': 10, 'Martinique': 6, 'Jane_Fonda': 12, 'Syria_A': 13, 'Urial': 5, 'Wow_Hold_An_Event': 9, 'Computer': 9, 'Mars_Exploration_Rover': 7, 'Howland_Island': 6, 'Gerald_Ford': 12, 'Felice_Beato': 2, 'Fermium': 3, 'Gallimimus': 14, 'Arctic': 0, 'Bioinformatics': 9, 'Mega_Man_X_%28character%29': 12, 'Mosque': 13, 'Humbert_Roque_Versace': 12, 'Anton_Alexander_von_Werner': 0, 'Indian_Railways': 13, 'List_of_European_Union_member_states_by_accession': 0, 'Iraq_War': 1, 'Robert_Schumann': 2, 'Boy_Scout': 12, 'Clone_Wars_%28Star_Wars%29': 9, 'Cretaceous': 14, 'Cadmium': 3, 'Gray_reef_shark': 5, 'S-mine': 12, 'Roan_Antelope': 5, 'Brothers_Grimm': 2, 'Sean_Connery': 8, 'Google': 12, 'Boat': 9, 'Colditz_Castle': 0, 'Isaac_Asimov': 7, 'Casimir_effect': 12, 'Parasaurolophus': 14, '13th_century': 13, 'Southern_Pacific_4449': 12, 'Rapping': 9, 'Potassium_nitrate': 3, 'Hubbard_Glacier': 10, 'Equatorial_Guinea': 6, 'Plover': 5, 'Frog': 14, 'Kigo': 9, 'Osiris': 2, 'Ultraviolet': 3, 'Report_From_Chernobyl': 4, 'Polish-Muscovite_War_%281605%E2%80%931618%29': 0, 'Herbert_Hoover': 12, 'Currency': 9, 'Nutrition': 9, '%C3%89ire': 8, 'Ben_Jonson': 8, 'Oceania': 6, 'Solar_eclipse': 7, 'Almond': 5, 'A_To_Z_Fundraising': 4, 'Saudi_Arabia': 13, 'Contact_lens': 9, 'Cerium': 3, 'Uruguay': 6, 'GNU_Project': 9, 'Chile_A': 6, 'Aarhus': 0, 'Universe': 7, 'Horse': 5, 'Wow_Photo_Exhibition': 4, 'Nitrogen_fixation': 9, 'Onion_dome': 0, 'Ziad_Jarrah': 1, 'Americas': 4, 'Asteroid': 7, 'Music_of_Albania': 0, 'Scanian_%28linguistics%29': 0, 'Prostate_cancer': 9, 'Plate_tectonics': 7, 'Yttrium' ...
# 9     844
# 12    562
# 5     430
# 2     419
# 13    376
# 4     348
# 11    325
# 10    325
# 0     320
# 8     293
# 6     265
# 3     218
# 7     188
# 1     177
# 14    142
# Name: count, dtype: int64
