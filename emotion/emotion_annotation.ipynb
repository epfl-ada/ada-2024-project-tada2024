# %%
import pandas as pd
import re

# Load the CSV file
df = pd.read_csv('extracted_sentences.csv', low_memory=False, index_col=0)

# Remove anything after '.' and '.' itself in the first column (assuming it's the index column)
df.index = df.index.map(lambda x: str(x).split('.')[0] if isinstance(x, str) else x)

# Remove '( URL )' and preceding '[...]' in all other columns (excluding the first column)
def remove_url(text):
    if isinstance(text, str):
        return re.sub(r'\[|\]\s*\(\s*URL\s*\)', '', text)
    return text

for column in df.columns:
    df[column] = df[column].apply(remove_url)

# Save the cleaned CSV file
df.to_csv('cleaned_extracted_sentences.csv')

print("CSV processing complete. The cleaned file is saved as 'cleaned_extracted_sentences.csv'.")
# Out:
# CSV processing complete. The cleaned file is saved as 'cleaned_extracted_sentences.csv'.

# %%
df.index
# Out:
# Index(['Royal_Marines', 'Recycling', 'Retreat_of_glaciers_since_1850',
#        'Remember_Girls_Like_Rajpura', 'Rutherfordium', 'Rule_of_St_Benedict',
#        'Red_dwarf', 'Romeo_and_Juliet', 'Rudyard_Kipling', 'Race',
#        ...
#        'Witold_Pilecki', 'What_Next_For_Tsunami_Orphans', 'Walt_Disney',
#        'Winter2005_Brick', 'Winter2005_Stop_Press', 'Wikispecies',
#        'William_Butler_Yeats', 'Western_painting', 'William_Ewart_Gladstone',
#        'World_War_II'],
#       dtype='object', length=5462)

# %%
import torch

if torch.cuda.is_available():
    print("GPU is available, using CUDA...")
    device = 0
else:
    print("GPU not available, using CPU...")
    device = -1  # CPU
# Out:
# GPU is available, using CUDA...

# %%
from transformers import AutoTokenizer, pipeline
# Function to truncate text to 512 tokens using the tokenizer
def truncate_text_with_tokenizer(text, tokenizer, max_length=512):
    encoded = tokenizer.encode(text, truncation=True, max_length=max_length)
    truncated_text = tokenizer.decode(encoded, skip_special_tokens=True)
    return truncated_text

# %%
# Load the tokenizer for the model
tokenizer = AutoTokenizer.from_pretrained("SamLowe/roberta-base-go_emotions")

# Apply truncation with the tokenizer to ensure the tokens of content is lower than the maximum
for column in df.columns:
    df[column] = df[column].apply(lambda x: truncate_text_with_tokenizer(x, tokenizer, max_length=512) if isinstance(x, str) else x)

df
# Out:
#                                                                                 0  \
# Royal_Marines                   Royal Marines Royal Marines  2007 Schools Wiki...
# Recycling                       Recycling Recycling  2007 Schools Wikipedia Se...
# Retreat_of_glaciers_since_1850  Retreat of glacier since 1850 Retreat of glaci...
# Remember_Girls_Like_Rajpura     How Remembering a Charity help  SOS Chidren 's...
# Rutherfordium                   Rutherfordium Rutherfordium  2007 Schools Wiki...
# ...                                                                           ...
# Wikispecies                     Wikispecies Wikispecies  2007 Schools Wikipedi...
# William_Butler_Yeats            William Butler Yeats William Butler Yeats  200...
# Western_painting                Western painting Western painting  2007 School...
# William_Ewart_Gladstone         William Ewart Gladstone William Ewart Gladston...
# World_War_II                    World War II World War II  2007 Schools Wikipe...
#
#                                                                                 1  \
# Royal_Marines                   Related subject :  Military History and War  N...
# Recycling                       Related subject :  Environment      The intern...
# Retreat_of_glaciers_since_1850  Related subject :  Climate and the Weather    ...
# Remember_Girls_Like_Rajpura                  She share with u her success story .
# Rutherfordium                   Related subject :  Chemical element  104  lawr...
# ...                                                                           ...
# Wikispecies                     Related subject :  Websites and the Internet  ...
# William_Butler_Yeats             Related subject :  Writers and critic      W.B .
# Western_painting                Related subject :  Art      Jan Vermeer , Girl...
# William_Ewart_Gladstone         Related subject :  Historical figure  ;  Polit...
# World_War_II                    Related subject :  British History Post 1900  ...
#
#                                                                                 2  \
# Royal_Marines                   A core component of the country 's Rapid Deplo...
# Recycling                        Environmental science  Environmental technolo...
# Retreat_of_glaciers_since_1850  Studied by glaciologists , the temporal coinci...
# Remember_Girls_Like_Rajpura     My Success Story I came to SOS Children 's Vil...
# Rutherfordium                   This is a highly radioactive synthetic element...
# ...                                                                           ...
# Wikispecies                     No Type of site Species directory Registration...
# William_Butler_Yeats                         Yeats in Dublin on 24 January 1908 .
# Western_painting                Until the early 20th century it relied primari...
# William_Ewart_Gladstone         He wa a notable political reformer , known for...
# World_War_II                    Date September 1 , 1939 – September 2 , 1945 L...
#
#                                                                                 3  \
# Royal_Marines                   The high level of training and competence , co...
# Recycling                       Recycling prevents useful material resource be...
# Retreat_of_glaciers_since_1850  Mid-latitude mountain range such a the  Himala...
# Remember_Girls_Like_Rajpura     At that point I could have never thought that ...
# Rutherfordium                   This element therefore ha no application and l...
# ...                                                                           ...
# Wikispecies                            It is an open , free directory of specie .
# William_Butler_Yeats            William Butler Yeats ( IPA : /jeɪts/ ) ( 13 Ju...
# Western_painting                Developments in Western painting historically ...
# William_Ewart_Gladstone         Gladstone wa famously at odds with  Queen Vict...
# World_War_II                    Emergence of the  United States  and the  Sovi...
#
#                                                                                 4  \
# Royal_Marines                   The Royal Marines are a component part of the ...
# Recycling                       Recycling is a key concept of modern  waste ma...
# Retreat_of_glaciers_since_1850  The Little Ice Age wa a period from about 1550...
# Remember_Girls_Like_Rajpura     My SOS mother wa very supportive and always en...
# Rutherfordium                   Rutherfordium is the first transactinide eleme...
# ...                                                                           ...
# Wikispecies                     Typical specie page A typical specie page woul...
# William_Butler_Yeats            Yeats , though born to an Anglo-Saxon Protesta...
# Western_painting                African art , Islamic art , Indian art , Chine...
# William_Ewart_Gladstone         She once complained `` He always address me a ...
# World_War_II                    Creation of First World and Second World spher...
#
#                                                                                 5  \
# Royal_Marines                   Role Corps of Royal Marines Cap Badge of the R...
# Recycling                       Recyclable material , also called `` recyclabl...
# Retreat_of_glaciers_since_1850  Subsequently , until about 1940 glacier around...
# Remember_Girls_Like_Rajpura     After getting grade ' A ' in class eight , my ...
# Rutherfordium                   History Rutherfordium ( named in honour of not...
# ...                                                                           ...
# Wikispecies                     Vernacular name are link to  Wikipedia  articl...
# William_Butler_Yeats                       Yeats also served a an Irish Senator .
# Western_painting                Initially serving  religious  patronage , West...
# William_Ewart_Gladstone         Early life Born in  Liverpool  ,  England  at ...
# World_War_II                               Decolonisation of the Allied Empires .
#
#                                                                                 6  \
# Royal_Marines                   As the United Kingdom Armed Forces ' specialis...
# Recycling                       They include  glass  , paper ,  aluminium  , a...
# Retreat_of_glaciers_since_1850  Glacial retreat slowed and even reversed , in ...
# Remember_Girls_Like_Rajpura     At school I played badminton and also particip...
# Rutherfordium                   Researchers there bombarded 242  Pu  with acce...
# ...                                                                           ...
# Wikispecies                     Community Portal The Wikispecies Community Por...
# William_Butler_Yeats            He wa awarded the Nobel Prize in Literature in...
# Western_painting                From the  Middle Ages  through the  Renaissanc...
# William_Ewart_Gladstone         The final `` s '' wa later dropped from the fa...
# World_War_II                    Combatants Allied power :   Soviet Union    Un...
#
#                                                                                 7  \
# Royal_Marines                   In common with the other armed force the Royal...
# Recycling                       Biodegradable waste , such a food waste or gar...
# Retreat_of_glaciers_since_1850  However , since 1980 a significant global warm...
# Remember_Girls_Like_Rajpura     Looking at my performance in badminton , my sp...
# Rutherfordium                   In 1969 researcher at the University of Califo...
# ...                                                                           ...
# Wikispecies                     The Wikispecies Village Pump is an area of Wik...
# William_Butler_Yeats            Early life and work When Yeats wa young , his ...
# Western_painting                Beginning with the  Baroque  era artist receiv...
# William_Ewart_Gladstone         Although Gladstone wa born and brought up in L...
# World_War_II                    Armed force from over seventy nation engaged i...
#
#                                                                                 8  \
# Royal_Marines                   Command , Control and Organisation Command of ...
# Recycling                       Recyclates need to be sorted and separated int...
# Retreat_of_glaciers_since_1850  In location such a the Andes of  South America...
# Remember_Girls_Like_Rajpura     After class twelve , I joined Guru Nanak Khals...
# Rutherfordium                   The UC group also stated that they could not r...
# ...                                                                           ...
# Wikispecies                         It is like a Wikipedia article 's talk page .
# William_Butler_Yeats            At first , the Yeats child were educated at ho...
# Western_painting                By the 19th century painter became liberated f...
# William_Ewart_Gladstone         Gladstone wa educated at Eton College , and in...
# World_War_II                    Spanning much of the globe , World War II resu...
#
#                                                                                 9  \
# Royal_Marines                   The operational capability of the Corps compri...
# Recycling                       Contamination of the recylates with other mate...
# Retreat_of_glaciers_since_1850  The retreat of mountain glacier , notably in w...
# Remember_Girls_Like_Rajpura     Hostel life wa a different experience all toge...
# Rutherfordium                   This resulted in an element naming controversy...
# ...                                                                           ...
# Wikispecies                     Currently it is the largest page on Wikispecies .
# William_Butler_Yeats            Their mother , who wa homesick for Sligo , ent...
# Western_painting                The idea `` art for art 's sake '' began to fi...
# William_Ewart_Gladstone         In December 1831 after sitting for his final e...
# World_War_II                       The war ended in 1945 with an Allied victory .
#
#                                 ...  \
# Royal_Marines                   ...
# Recycling                       ...
# Retreat_of_glaciers_since_1850  ...
# Remember_Girls_Like_Rajpura     ...
# Rutherfordium                   ...
# ...                             ...
# Wikispecies                     ...
# William_Butler_Yeats            ...
# Western_painting                ...
# William_Ewart_Gladstone         ...
# World_War_II                    ...
#
#                                                                               721  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    United Nations Because the  League of Nations ...
#
#                                                                               722  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    The UN operates within the parameter of the Un...
#
#                                                                               723  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    One of the first action of the United Nations ...
#
#                                                                               724  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    Names The term most used in the United Kingdom...
#
#                                                                               725  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    Thus the Oxford University Press us The Oxford...
#
#                                                                               726  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    The OED report the first use of `` Second Worl...
#
#                                                                               727  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    Wells in 1930 , although it may well have been...
#
#                                                                               728  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    The term wa immediately used when war wa decla...
#
#                                                                               729  \
# Royal_Marines                                                                 NaN
# Recycling                                                                     NaN
# Retreat_of_glaciers_since_1850                                                NaN
# Remember_Girls_Like_Rajpura                                                   NaN
# Rutherfordium                                                                 NaN
# ...                                                                           ...
# Wikispecies                                                                   NaN
# William_Butler_Yeats                                                          NaN
# Western_painting                                                              NaN
# William_Ewart_Gladstone                                                       NaN
# World_War_II                    Retrieved from `` http : //en.wikipedia.org/wi...
#
#                                                         730
# Royal_Marines                                           NaN
# Recycling                                               NaN
# Retreat_of_glaciers_since_1850                          NaN
# Remember_Girls_Like_Rajpura                             NaN
# Rutherfordium                                           NaN
# ...                                                     ...
# Wikispecies                                             NaN
# William_Butler_Yeats                                    NaN
# Western_painting                                        NaN
# William_Ewart_Gladstone                                 NaN
# World_War_II                    See also our  Disclaimer  .
#
# [5462 rows x 731 columns]

# %%
# Load model
emotion_analyzer = pipeline("text-classification", model="SamLowe/roberta-base-go_emotions", top_k=None, device=device)

for column in df.columns:
    df[column] = df[column].apply(lambda x: emotion_analyzer(x) if pd.notna(x) else x)

# Print sample results
df.to_csv('processed_extracted_sentences.csv')
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
